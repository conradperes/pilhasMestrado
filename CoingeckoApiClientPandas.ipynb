# %% [markdown]
# <a href="https://colab.research.google.com/github/conradperes/pilhasMestrado/blob/master/CoingeckoApiClientPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Conheça o Colab</h1>
#
# Se você já conhece bem o Colab, confira este vídeo para saber mais sobre as tabelas interativas, a visualização do histórico de código executado e o Palette de comandos.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Miniatura de um vídeo mostrando três recursos interessantes do Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)

# %%
import pandas as pd

# %%
data = {'Product': ['Desktop Computer','Printer','Tablet','Monitor'],
        'Price': [1200,150,300,450]
        }

df = pd.DataFrame(data, columns = ['Product', 'Price'])

print (df)
# Out:
#             Product  Price
# 0  Desktop Computer   1200
# 1           Printer    150
# 2            Tablet    300
# 3           Monitor    450

# %%
data = {'Product': ['Desktop Computer','Printer','Tablet','Monitor'],
        'Price': [1200,150,300,450]
        }

df = pd.DataFrame(data, columns = ['Product', 'Price'])

df.to_excel (r'export_dataframe.xlsx', index = False, header=True)

# %%
df
# Out:
#             Product  Price
# 0  Desktop Computer   1200
# 1           Printer    150
# 2            Tablet    300
# 3           Monitor    450

# %%
import requests
import json

# Get the feed
r = requests.get("https://reqres.in/api/products/3")
print(r.text)

# Convert it to a Python dictionar
data = json.loads(r.text)

# Loop through the result.
for item in data['data']:
    print("id: %s" % data['data']['id'])
    print("Year: %s" % data['data']['year'])
    print("Text: %s" % data['support']['text'])
    print("URL: %s" % data['support']['url'])
    #print("Video Category: %s" % (item['category']))
    #print("Video ID: %s" % (item['id']))
    #print("Video Rating: %f" % (item['rating']))
    #print("Embed URL: %s" % (item['player']['default']))
# Out:
# {"data":{"id":3,"name":"true red","year":2002,"color":"#BF1932","pantone_value":"19-1664"},"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards server costs are appreciated!"}}
# id: 3
# Year: 2002
# Text: To keep ReqRes free, contributions towards server costs are appreciated!
# URL: https://reqres.in/#support-heading
# id: 3
# Year: 2002
# Text: To keep ReqRes free, contributions towards server costs are appreciated!
# URL: https://reqres.in/#support-heading
# id: 3
# Year: 2002
# Text: To keep ReqRes free, contributions towards server costs are appreciated!
# URL: https://reqres.in/#support-heading
# id: 3
# Year: 2002
# Text: To keep ReqRes free, contributions towards server costs are appreciated!
# URL: https://reqres.in/#support-heading
# id: 3
# Year: 2002
# Text: To keep ReqRes free, contributions towards server costs are appreciated!
# URL: https://reqres.in/#support-heading

# %%
pip install pycoingecko
# Out:
# Collecting pycoingecko
#   Downloading pycoingecko-2.2.0-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pycoingecko) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pycoingecko) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pycoingecko) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pycoingecko) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pycoingecko) (1.24.3)
# Installing collected packages: pycoingecko
# Successfully installed pycoingecko-2.2.0

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
# /simple/price endpoint with the required parameters
>>> cg.get_price(ids='bitcoin', vs_currencies='usd')
{'bitcoin': {'usd': 3462.04}}

>>> cg.get_price(ids='bitcoin,litecoin,ethereum', vs_currencies='usd')
# OR (lists can be used for multiple-valued arguments)
>>> cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies='usd')
{'bitcoin': {'usd': 3461.27}, 'ethereum': {'usd': 106.92}, 'litecoin': {'usd': 32.72}}

>>> cg.get_price(ids='bitcoin,litecoin,ethereum', vs_currencies='usd,eur')
# OR (lists can be used for multiple-valued arguments)
>>> cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies=['usd', 'eur'])
{'bitcoin': {'usd': 3459.39, 'eur': 3019.33}, 'ethereum': {'usd': 106.91, 'eur': 93.31}, 'litecoin': {'usd': 32.72, 'eur': 28.56}}

# optional parameters can be passed as defined in the API doc (https://www.coingecko.com/api/docs/v3)
>>> cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap='true', include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')
{'bitcoin': {'usd': 3458.74, 'usd_market_cap': 60574330199.29028, 'usd_24h_vol': 4182664683.6247883, 'usd_24h_change': 1.2295378479069035, 'last_updated_at': 1549071865}}
# OR (also booleans can be used for boolean type arguments)
>>> cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap=True, include_24hr_vol=True, include_24hr_change=True, include_last_updated_at=True)
{'bitcoin': {'usd': 3458.74, 'usd_market_cap': 60574330199.29028, 'usd_24h_vol': 4182664683.6247883, 'usd_24h_change': 1.2295378479069035, 'last_updated_at': 1549071865}}
# Out:
# {'bitcoin': {'last_updated_at': 1549071865,
#   'usd': 3458.74,
#   'usd_24h_change': 1.2295378479069035,
#   'usd_24h_vol': 4182664683.6247883,
#   'usd_market_cap': 60574330199.29028}}

# %%
cg.get_coins_list()
# Out:
# [{'id': '01coin', 'name': '01coin', 'symbol': 'zoc'},
#  {'id': '0-5x-long-algorand-token',
#   'name': '0.5X Long Algorand Token',
#   'symbol': 'algohalf'},
#  {'id': '0-5x-long-altcoin-index-token',
#   'name': '0.5X Long Altcoin Index Token',
#   'symbol': 'althalf'},
#  {'id': '0-5x-long-balancer-token',
#   'name': '0.5X Long Balancer Token',
#   'symbol': 'balhalf'},
#  {'id': '0-5x-long-bitcoin-cash-token',
#   'name': '0.5X Long Bitcoin Cash Token',
#   'symbol': 'bchhalf'},
#  {'id': '0-5x-long-bitcoin-sv-token',
#   'name': '0.5X Long Bitcoin SV Token',
#   'symbol': 'bsvhalf'},
#  {'id': '0-5x-long-bitcoin-token',
#   'name': '0.5X Long Bitcoin Token',
#   'symbol': 'half'},
#  {'id': '0-5x-long-cardano-token',
#   'name': '0.5X Long Cardano Token',
#   'symbol': 'adahalf'},
#  {'id': '0-5x-long-chainlink-token',
#   'name': '0.5X Long Chainlink Token',
#   'symbol': 'linkhalf'},
#  {'id': '0-5x-long-cosmos-token',
#   'name': '0.5X Long Cosmos Token',
#   'symbol': 'atomhalf'},
#  {'id': '0-5x-long-defi-index-token',
#   'name': '0.5X Long DeFi Index Token',
#   'symbol': 'defihalf'},
#  {'id': '0-5x-long-dogecoin-token',
#   'name': '0.5X Long Dogecoin Token',
#   'symbol': 'dogehalf'},
#  {'id': '0-5x-long-dragon-index-token',
#   'name': '0.5X Long Dragon Index Token',
#   'symbol': 'drgnhalf'},
#  {'id': '0-5x-long-echange-token-index-token',
#   'name': '0.5X Long Exchange Token Index Token',
#   'symbol': 'exchhalf'},
#  {'id': '0-5x-long-eos-token',
#   'name': '0.5X Long EOS Token',
#   'symbol': 'eoshalf'},
#  {'id': '0-5x-long-ethereum-classic-token',
#   'name': '0.5X Long Ethereum Classic Token',
#   'symbol': 'etchalf'},
#  {'id': '0-5x-long-ethereum-token',
#   'name': '0.5X Long Ethereum Token',
#   'symbol': 'ethhalf'},
#  {'id': '0-5x-long-kyber-network-token',
#   'name': '0.5X Long Kyber Network Token',
#   'symbol': 'knchalf'},
#  {'id': '0-5x-long-matic-token',
#   'name': '0.5X Long Matic Token',
#   'symbol': 'matichalf'},
#  {'id': '0-5x-long-okb-token',
#   'name': '0.5X Long OKB Token',
#   'symbol': 'OKBHALF'},
#  {'id': '0-5x-long-privacy-index-token',
#   'name': '0.5X Long Privacy Index Token',
#   'symbol': 'privhalf'},
#  {'id': '0-5x-long-shitcoin-index-token',
#   'name': '0.5X Long Shitcoin Index Token',
#   'symbol': 'halfshit'},
#  {'id': '0-5x-long-swipe-token',
#   'name': '0.5X Long Swipe Token',
#   'symbol': 'sxphalf'},
#  {'id': '0-5x-long-tether-gold-token',
#   'name': '0.5X Long Tether Gold Token',
#   'symbol': 'xauthalf'},
#  {'id': '0-5x-long-tezos-token',
#   'name': '0.5X Long Tezos Token',
#   'symbol': 'xtzhalf'},
#  {'id': '0-5x-long-theta-network-token',
#   'name': '0.5X Long Theta Network Token',
#   'symbol': 'thetahalf'},
#  {'id': '0-5x-long-xrp-token',
#   'name': '0.5X Long XRP Token',
#   'symbol': 'xrphalf'},
#  {'id': '0cash', 'name': '0cash', 'symbol': 'zch'},
#  {'id': '0chain', 'name': '0chain', 'symbol': 'zcn'},
#  {'id': '0x', 'name': '0x', 'symbol': 'zrx'},
#  {'id': '0xcert', 'name': '0xcert', 'symbol': 'zxc'},
#  {'id': '0xcharts', 'name': '0xCharts', 'symbol': '0xc'},
#  {'id': '0xmonero', 'name': '0xMonero', 'symbol': '0xmr'},
#  {'id': '0xpad', 'name': '0xPAD', 'symbol': '0xpad'},
#  {'id': '1000-florida',
#   'name': 'RealT Token - 1000 Florida Ave, Akron, OH 44314',
#   'symbol': 'realtoken-s-1000-florida-ave-akron-oh'},
#  {'id': '10024-10028-appoline',
#   'name': 'RealT Token -10024-10028 Appoline St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-10024-10028-appoline-st-detroit-mi'},
#  {'id': '10084-grayton',
#   'name': 'RealT Token - 10084 Grayton St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10084-grayton-st-detroit-mi'},
#  {'id': '100man', 'name': '100Man', 'symbol': 'man'},
#  {'id': '100x-coin', 'name': '100xCoin', 'symbol': '100x'},
#  {'id': '10604-somerset',
#   'name': 'RealT Token - 10604 Somerset Ave, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10604-somerset-ave-detroit-mi'},
#  {'id': '10612-somerset',
#   'name': 'RealT Token - 10612 Somerset Ave, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10612-somerset-ave-detroit-mi'},
#  {'id': '10616-mckinney',
#   'name': 'RealT Token - 10616 McKinney St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10616-mckinney-st-detroit-mi'},
#  {'id': '10617-hathaway',
#   'name': 'RealT Token - 10617 Hathaway Ave, Cleveland, OH 44108',
#   'symbol': 'realtoken-s-10617-hathaway-ave-cleveland-oh'},
#  {'id': '10629-mckinney',
#   'name': 'RealT Token - 10629 McKinney St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10629-mckinney-st-detroit-mi'},
#  {'id': '10639-stratman',
#   'name': 'RealT Token - 10639 Stratman St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10639-stratman-st-detroit-mi'},
#  {'id': '10700-whittier',
#   'name': 'RealT Token - 10700 Whittier Ave, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10700-whittier-ave-detroit-mi'},
#  {'id': '10974-worden',
#   'name': 'RealT Token - 10974 Worden St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-10974-worden-st-detroit-mi'},
#  {'id': '11078-longview',
#   'name': 'RealT Token - 11078 Longview St, Detroit, MI 48213',
#   'symbol': 'realtoken-s-11078-longview-st-detroit-mi'},
#  {'id': '11078-wayburn',
#   'name': 'RealT Token - 11078 Wayburn St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-11078-wayburn-st-detroit-mi'},
#  {'id': '11201-college',
#   'name': 'RealT Token - 11201 College St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-11201-college-st-detroit-mi'},
#  {'id': '11300-roxbury',
#   'name': 'RealT Token - 11300 Roxbury St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-11300-roxbury-st-detroit-mi'},
#  {'id': '11653-nottingham',
#   'name': 'RealT Token - 11653 Nottingham Rd, Detroit, MI 48224',
#   'symbol': 'realtoken-s-11653-nottingham-rd-detroit-mi'},
#  {'id': '11957-olga',
#   'name': 'RealT Token - 11957 Olga St, Detroit, MI 48213',
#   'symbol': 'realtoken-s-11957-olga-st-detroit-mi'},
#  {'id': '12334-lansdowne',
#   'name': 'RealT Token - 12334 Lansdowne Street, Detroit, MI 48224',
#   'symbol': 'realtoken-s-12334-lansdowne-street-detroit-mi'},
#  {'id': '12405-santa-rosa',
#   'name': 'RealT Token - 12405 Santa Rosa Dr, Detroit, MI 48204',
#   'symbol': 'realtoken-s-12405-santa-rosa-dr-detroit-mi'},
#  {'id': '12409-whitehill',
#   'name': 'RealT Token - 12409 Whitehill St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-12409-whitehill-st-detroit-mi'},
#  {'id': '1244-s-avers',
#   'name': 'RealT Token - 1244 S. Avers St, Chicago, IL 60623',
#   'symbol': 'realtoken-s-1244-s.avers-st-chicago-il'},
#  {'id': '12866-lauder',
#   'name': 'RealT Token - 12866 Lauder St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-12866-lauder-st-detroit-mi'},
#  {'id': '12ships', 'name': '12Ships', 'symbol': 'TSHP'},
#  {'id': '13045-wade',
#   'name': 'RealT Token - 13045 Wade St, Detroit, MI 48213',
#   'symbol': 'realtoken-s-13045-wade-st-detroit-mi'},
#  {'id': '13114-glenfield',
#   'name': 'RealT Token - 13114 Glenfield Ave, Detroit, MI 48213',
#   'symbol': 'realtoken-s-13114-glenfield-ave-detroit-mi'},
#  {'id': '13116-kilbourne',
#   'name': 'RealT Token - 13116 Kilbourne Ave, Detroit, MI 48213',
#   'symbol': 'realtoken-s-13116-kilbourne-ave-detroit-mi'},
#  {'id': '1337', 'name': 'Elite', 'symbol': '1337'},
#  {'id': '13606-winthrop',
#   'name': 'RealT Token - 13606 Winthrop St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-13606-winthrop-st-detroit-mi'},
#  {'id': '13991-warwick',
#   'name': 'RealT Token -13991 Warwick St, Detroit, MI, 48223',
#   'symbol': 'realtoken-s-13991-warwick-st-detroit-mi'},
#  {'id': '14066-santa-rosa',
#   'name': 'RealT Token - 14066 Santa Rosa Dr, Detroit, MI 48238',
#   'symbol': 'realtoken-s-14066-santa-rosa-dr-detroit-mi'},
#  {'id': '14078-carlisle',
#   'name': 'RealT Token - 14078 Carlisle St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-14078-carlisle-st-detroit-mi'},
#  {'id': '14229-wilshire',
#   'name': 'RealT Token - 14229 Wilshire Dr, Detroit, MI 48213',
#   'symbol': 'realtoken-s-14229-wilshire-dr-detroit-mi'},
#  {'id': '14231-strathmoor',
#   'name': 'RealT Token - 14231 Strathmoor St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-14231-strathmoor-st-detroit-mi'},
#  {'id': '14319-rosemary',
#   'name': 'RealT Token - 14319 Rosemary St, Detroit, MI 48213',
#   'symbol': 'realtoken-s-14319-rosemary-st-detroit-mi'},
#  {'id': '14494-chelsea',
#   'name': 'RealT Token - 14494 Chelsea Ave, Detroit, MI 48213',
#   'symbol': 'realtoken-s-14494-chelsea-ave-detroit-mi'},
#  {'id': '14825-wilfred',
#   'name': 'RealT Token - 14825 Wilfred St, Detroit, MI 48213',
#   'symbol': 'realtoken-s-14825-wilfried-st-detroit-mi'},
#  {'id': '14882-troester',
#   'name': 'RealT Token - 14882 Troester St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-14882-troester-st-detroit-mi'},
#  {'id': '14918-joy',
#   'name': 'RealT Token - 14918 Joy Rd, Detroit, MI 48228',
#   'symbol': 'realtoken-s-14918-joy-rd-detroit-mi'},
#  {'id': '15039-ward',
#   'name': 'RealT Token - 15039 Ward Ave, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15039-ward-ave-detroit-mi'},
#  {'id': '15048-freeland',
#   'name': 'RealT Token - 15048 Freeland St, Detroit, MI, 48227',
#   'symbol': 'realtoken-s-15048-freeland-st-detroit-mi'},
#  {'id': '15095-hartwell',
#   'name': 'RealT Token -15095 Hartwell St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15095-hartwell-st-detroit-mi'},
#  {'id': '15350-greydale',
#   'name': 'RealT Token - 15350 Greydale St, Detroit, MI 48223',
#   'symbol': 'realtoken-s-15350-greydale-st-detroit-mi'},
#  {'id': '15373-parkside',
#   'name': 'RealT Token - 15373 Parkside St, Detroit, MI 48238',
#   'symbol': 'realtoken-s-15373-parkside-st-detroit-mi'},
#  {'id': '1542-s-ridgeway',
#   'name': 'RealT Token - 1542 S Ridgeway Ave, Chicago, IL 60623',
#   'symbol': 'realtoken-s-1542-s.ridgeway-ave-chicago-il'},
#  {'id': '15634-liberal',
#   'name': 'RealT Token - 15634 Liberal St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-15634-liberal-st-detroit-mi'},
#  {'id': '15753-hartwell',
#   'name': 'RealT Token - 15753 Hartwell St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15753-hartwell-st-detroit-mi'},
#  {'id': '15770-prest',
#   'name': 'RealT Token - 15770 Prest St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15770-prest-st-detroit-mi'},
#  {'id': '15777-ardmore',
#   'name': 'RealT Token - 15777 Ardmore St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15777-ardmore-st-detroit-mi'},
#  {'id': '15778-manor',
#   'name': 'RealT Token - 15778 Manor St, Detroit, MI 48238',
#   'symbol': 'realtoken-s-15778-manor-st-detroit-mi'},
#  {'id': '15784-monte-vista',
#   'name': 'RealT Token - 15784 Monte Vista St, Detroit, MI 48238',
#   'symbol': 'realtoken-s-15784-monte-vista-st-detroit-mi'},
#  {'id': '15796-hartwell',
#   'name': 'RealT Token - 15796 Hartwell St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15796-hartwell-st-detroit-mi'},
#  {'id': '15860-hartwell',
#   'name': 'RealT Token - 15860 Hartwell St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-15860-hartwell-st-detroit-mi'},
#  {'id': '1617-s-avers',
#   'name': 'RealT Token - 1617 S Avers Ave, Chicago, IL 60623',
#   'symbol': 'realtoken-s-1617-s.avers-ave-chicago-il'},
#  {'id': '16200-fullerton',
#   'name': 'RealT Token - 16200 Fullerton Ave, Detroit, MI 48227',
#   'symbol': 'realtoken-s-16200-fullerton-ave-detroit-mi'},
#  {'id': '17500-evergreen',
#   'name': 'RealT Token - 17500 Evergreen Rd, Detroit, MI 48219',
#   'symbol': 'realtoken-s-17500-evergreen-rd-detroit-mi'},
#  {'id': '17809-charest',
#   'name': 'RealT Token - 17809 Charest St, Detroit, MI 48212',
#   'symbol': 'realtoken-s-17809-charest-st-detroit-mi'},
#  {'id': '17813-bradford',
#   'name': 'RealT Token - 17813 Bradford St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-17813-bradford-st-detroit-mi'},
#  {'id': '1815-s-avers',
#   'name': 'RealT Token - 1815 S Avers Ave, Chicago, IL 60623',
#   'symbol': 'realtoken-s-1815-s.avers-ave-chicago-il'},
#  {'id': '18273-monte-vista',
#   'name': 'RealT Token - 18273 Monte Vista St, Detroit, MI 48221',
#   'symbol': 'realtoken-s-18273-monte-vista-st-detroit-mi'},
#  {'id': '18276-appoline',
#   'name': 'RealT Token - 18276 Appoline St, Detroit, MI 48235',
#   'symbol': 'realtoken-s-18276-appoline-st-detroit-mi'},
#  {'id': '18433-faust',
#   'name': 'RealT Token - 18433 Faust Ave, Detroit, MI, 48219',
#   'symbol': 'realtoken-s-18433-faust-ave-detroit-mi'},
#  {'id': '18466-fielding',
#   'name': 'RealT Token -18466 Fielding St, Detroit, MI 48219',
#   'symbol': 'realtoken-s-18466-fielding-st-detroit-mi'},
#  {'id': '18481-westphalia',
#   'name': 'RealT Token - 18481 Westphalia St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-18481-westphalia-st-detroit-mi'},
#  {'id': '18776-sunderland',
#   'name': 'RealT Token - 18776 Sunderland Rd, Detroit, MI 48219',
#   'symbol': 'realtoken-s-18776-sunderland-rd-detroit-mi'},
#  {'id': '18900-mansfield',
#   'name': 'RealT Token - 18900 Mansfield St, Detroit, MI 48235',
#   'symbol': 'realtoken-s-18900-mansfield-st-detroit-mi'},
#  {'id': '18983-alcoy',
#   'name': 'RealT Token - 18983 Alcoy Ave, Detroit, MI 48205',
#   'symbol': 'realtoken-s-18983-alcoy-ave-detroit-mi'},
#  {'id': '19020-rosemont',
#   'name': 'RealT Token - 19020 Rosemont Ave, Detroit, MI 48219',
#   'symbol': 'realtoken-s-19020-rosemont-ave-detroit-mi'},
#  {'id': '19136-tracey',
#   'name': 'RealT Token - 19136 Tracey St, Detroit MI 48235',
#   'symbol': 'realtoken-s-19136-tracey-st-detroit-mi'},
#  {'id': '19163-mitchell',
#   'name': 'RealT Token - 19163 Mitchell St, Detroit, MI 48234',
#   'symbol': 'realtoken-s-19163-mitchell-st-detroit-mi'},
#  {'id': '19200-strasburg',
#   'name': 'RealT Token - 19200 Strasburg St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-19200-strasburg-st-detroit-mi'},
#  {'id': '19201-westphalia',
#   'name': 'RealT Token - 19201 Westphalia St, Detroit, MI 48205',
#   'symbol': 'realtoken-s-19201-westphalia-st-detroit-mi'},
#  {'id': '19218-houghton',
#   'name': 'RealT Token - 19218 Houghton St, Detroit, MI 48219',
#   'symbol': 'realtoken-s-19218-houghton-st-detroit-mi'},
#  {'id': '19311-keystone',
#   'name': 'RealT Token - 19311 Keystone St, Detroit, MI 48234',
#   'symbol': 'realtoken-s-19311-keystone-st-detroit-mi'},
#  {'id': '19317-gable',
#   'name': 'RealT Token - 19317 Gable St, Detroit, MI 48234',
#   'symbol': 'realtoken-s-19317-gable-st-detroit-mi'},
#  {'id': '19333-moenart',
#   'name': 'RealT Token - 19333 Moenart St, Detroit MI 48234',
#   'symbol': 'realtoken-s-19333-moenart-st-detroit-mi'},
#  {'id': '19596-goulburn',
#   'name': 'RealT Token - 19596 Goulburn Ave, Detroit, MI 48205',
#   'symbol': 'realtoken-s-19596-goulburn-st-detroit-mi'},
#  {'id': '19996-joann',
#   'name': 'RealT Token - 19996 Joann Ave, Detroit, MI 48205',
#   'symbol': 'realtoken-s-19996-joann-ave-detroit-mi'},
#  {'id': '1art', 'name': 'ArtWallet', 'symbol': '1art'},
#  {'id': '1box', 'name': '1BOX', 'symbol': '1box'},
#  {'id': '1doge', 'name': '1Doge', 'symbol': '1doge'},
#  {'id': '1-dollar', 'name': '1 Dollar', 'symbol': 'oneusd'},
#  {'id': '1eco', 'name': '1eco', 'symbol': '1eco'},
#  {'id': '1inch', 'name': '1inch', 'symbol': '1inch'},
#  {'id': '1million-nfts', 'name': '1MillionNFTs', 'symbol': '1mil'},
#  {'id': '1million-token', 'name': '1Million Token', 'symbol': '1mt'},
#  {'id': '1nft', 'name': '1NFT', 'symbol': '1nft'},
#  {'id': '1peco', 'name': '1peco', 'symbol': '1peco'},
#  {'id': '1sol', 'name': '1Sol', 'symbol': '1sol'},
#  {'id': '1swap', 'name': '1Swap', 'symbol': '1swap'},
#  {'id': '1tronic', 'name': '1TRONIC', 'symbol': '1trc'},
#  {'id': '1-up', 'name': '1-UP', 'symbol': '1-up'},
#  {'id': '1world', 'name': '1World', 'symbol': '1wo'},
#  {'id': '1x-long-btc-implied-volatility-token',
#   'name': 'Bitcoin Volatility Token',
#   'symbol': 'bvol'},
#  {'id': '1x-short-algorand-token',
#   'name': '1X Short Algorand Token',
#   'symbol': 'algohedge'},
#  {'id': '1x-short-bitcoin-cash-token',
#   'name': '1X Short Bitcoin Cash Token',
#   'symbol': 'bchhedge'},
#  {'id': '1x-short-bitcoin-token',
#   'name': '1X Short Bitcoin Token',
#   'symbol': 'hedge'},
#  {'id': '1x-short-bnb-token',
#   'name': '1X Short BNB Token',
#   'symbol': 'bnbhedge'},
#  {'id': '1x-short-btc-implied-volatility',
#   'name': 'Inverse Bitcoin Volatility Token',
#   'symbol': 'ibvol'},
#  {'id': '1x-short-cardano-token',
#   'name': '1X Short Cardano Token',
#   'symbol': 'adahedge'},
#  {'id': '1x-short-chainlink-token',
#   'name': '1X Short Chainlink Token',
#   'symbol': 'LINKHEDGE'},
#  {'id': '1x-short-compound-token-token',
#   'name': '1X Short Compound Token Token',
#   'symbol': 'comphedge'},
#  {'id': '1x-short-cosmos-token',
#   'name': '1X Short Cosmos Token',
#   'symbol': 'atomhedge'},
#  {'id': '1x-short-defi-index-token',
#   'name': '1X Short DeFi Index Token',
#   'symbol': 'defihedge'},
#  {'id': '1x-short-dogecoin-token',
#   'name': '1X Short Dogecoin Token',
#   'symbol': 'dogehedge'},
#  {'id': '1x-short-eos-token',
#   'name': '1X Short EOS Token',
#   'symbol': 'eoshedge'},
#  {'id': '1x-short-ethereum-token',
#   'name': '1X Short Ethereum Token',
#   'symbol': 'ethhedge'},
#  {'id': '1x-short-exchange-token-index-token',
#   'name': '1X Short Exchange Token Index Token',
#   'symbol': 'exchhedge'},
#  {'id': '1x-short-litecoin-token',
#   'name': '1X Short Litecoin Token',
#   'symbol': 'ltchedge'},
#  {'id': '1x-short-matic-token',
#   'name': '1X Short Matic Token',
#   'symbol': 'matichedge'},
#  {'id': '1x-short-okb-token',
#   'name': '1X Short OKB Token',
#   'symbol': 'okbhedge'},
#  {'id': '1x-short-privacy-index-token',
#   'name': '1X Short Privacy Index Token',
#   'symbol': 'privhedge'},
#  {'id': '1x-short-shitcoin-index-token',
#   'name': '1X Short Shitcoin Index Token',
#   'symbol': 'hedgeshit'},
#  {'id': '1x-short-swipe-token',
#   'name': '1X Short Swipe Token',
#   'symbol': 'sxphedge'},
#  {'id': '1x-short-tezos-token',
#   'name': '1X Short Tezos Token',
#   'symbol': 'xtzhedge'},
#  {'id': '1x-short-theta-network-token',
#   'name': '1X Short Theta Network Token',
#   'symbol': 'thetahedge'},
#  {'id': '1x-short-tomochain-token',
#   'name': '1X Short TomoChain Token',
#   'symbol': 'tomohedge'},
#  {'id': '1x-short-trx-token',
#   'name': '1X Short TRX Token',
#   'symbol': 'trxhedge'},
#  {'id': '1x-short-vechain-token',
#   'name': '1X Short VeChain Token',
#   'symbol': 'vethedge'},
#  {'id': '1x-short-xrp-token',
#   'name': '1X Short XRP Token',
#   'symbol': 'xrphedge'},
#  {'id': '20200-lesure',
#   'name': 'RealT Token - 20200 Lesure St, Detroit, MI 48235',
#   'symbol': 'realtoken-s-20200-lesure-st-detroit-mi'},
#  {'id': '2022moon', 'name': '2022MOON', 'symbol': '2022m'},
#  {'id': '2030-floki', 'name': '2030 Floki', 'symbol': '2030Floki'},
#  {'id': '25097-andover',
#   'name': 'RealT Token - 25097 Andover Dr, Dearborn Heights, MI 48125',
#   'symbol': 'realtoken-s-25097-andover-dr-dearborn-heights-mi'},
#  {'id': '272-n-e-42nd-court',
#   'name': 'RealT Token - 272 N.E. 42nd Court, Deerfield Beach, FL 33064',
#   'symbol': 'realtoken-s-272-n.e.-42nd-court-deerfield-beach-fl'},
#  {'id': '28vck', 'name': '28VCK', 'symbol': 'vck'},
#  {'id': '2acoin', 'name': '2ACoin', 'symbol': 'arms'},
#  {'id': '2-chains', 'name': '2 Chains', 'symbol': '2chainlinks'},
#  {'id': '2crazynft', 'name': '2crazyNFT', 'symbol': '2crz'},
#  {'id': '2gather', 'name': '2gather', 'symbol': 'two'},
#  {'id': '2gether-2', 'name': '2gether', 'symbol': '2gt'},
#  {'id': '2give', 'name': '2GIVE', 'symbol': '2give'},
#  {'id': '2goshi', 'name': '2GoShi', 'symbol': '2goshi'},
#  {'id': '2key', 'name': '2key.network', 'symbol': '2key'},
#  {'id': '2local-2', 'name': '2local', 'symbol': '2lc'},
#  {'id': '2omb-finance', 'name': '2omb Finance', 'symbol': '2omb'},
#  {'id': '2share', 'name': '2SHARE', 'symbol': '2shares'},
#  {'id': '2x2', 'name': '2X2', 'symbol': '2x2'},
#  {'id': '300fit', 'name': '300FIT', 'symbol': 'fit'},
#  {'id': '3432-harding',
#   'name': 'RealT Token - 3432 Harding Street, Detroit, MI, 48214',
#   'symbol': 'realtoken-s-3432-harding-street-detroit-mi'},
#  {'id': '3x-long-algorand-token',
#   'name': '3X Long Algorand Token',
#   'symbol': 'algobull'},
#  {'id': '3x-long-altcoin-index-token',
#   'name': '3X Long Altcoin Index Token',
#   'symbol': 'altbull'},
#  {'id': '3x-long-balancer-token',
#   'name': '3X Long Balancer Token',
#   'symbol': 'balbull'},
#  {'id': '3x-long-bilira-token',
#   'name': '3X Long BiLira Token',
#   'symbol': 'trybbull'},
#  {'id': '3x-long-bitcoin-cash-token',
#   'name': '3X Long Bitcoin Cash Token',
#   'symbol': 'bchbull'},
#  {'id': '3x-long-bitcoin-sv-token',
#   'name': '3X Long Bitcoin SV Token',
#   'symbol': 'bsvbull'},
#  {'id': '3x-long-bitcoin-token',
#   'name': '3X Long Bitcoin Token',
#   'symbol': 'bull'},
#  {'id': '3x-long-bnb-token', 'name': '3X Long BNB Token', 'symbol': 'bnbbull'},
#  {'id': '3x-long-cardano-token',
#   'name': '3X Long Cardano Token',
#   'symbol': 'adabull'},
#  {'id': '3x-long-chainlink-token',
#   'name': '3X Long Chainlink Token',
#   'symbol': 'linkbull'},
#  {'id': '3x-long-compound-token-token',
#   'name': '3X Long Compound Token Token',
#   'symbol': 'compbull'},
#  {'id': '3x-long-compound-usdt-token',
#   'name': '3X Long Compound USDT Token',
#   'symbol': 'cusdtbull'},
#  {'id': '3x-long-cosmos-token',
#   'name': '3X Long Cosmos Token',
#   'symbol': 'atombull'},
#  {'id': '3x-long-defi-index-token',
#   'name': '3X Long DeFi Index Token',
#   'symbol': 'defibull'},
#  {'id': '3x-long-dogecoin-token',
#   'name': '3X Long Dogecoin Token',
#   'symbol': 'dogebull'},
#  {'id': '3x-long-dragon-index-token',
#   'name': '3X Long Dragon Index Token',
#   'symbol': 'drgnbull'},
#  {'id': '3x-long-eos-token', 'name': '3X Long EOS Token', 'symbol': 'eosbull'},
#  {'id': '3x-long-ethereum-classic-token',
#   'name': '3X Long Ethereum Classic Token',
#   'symbol': 'etcbull'},
#  {'id': '3x-long-ethereum-token',
#   'name': '3X Long Ethereum Token',
#   'symbol': 'ethbull'},
#  {'id': '3x-long-exchange-token-index-token',
#   'name': '3X Long Exchange Token Index Token',
#   'symbol': 'exchbull'},
#  {'id': '3x-long-huobi-token-token',
#   'name': '3X Long Huobi Token Token',
#   'symbol': 'htbull'},
#  {'id': '3x-long-kyber-network-token',
#   'name': '3X Long Kyber Network Token',
#   'symbol': 'kncbull'},
#  {'id': '3x-long-leo-token', 'name': '3X Long LEO Token', 'symbol': 'leobull'},
#  {'id': '3x-long-litecoin-token',
#   'name': '3X Long Litecoin Token',
#   'symbol': 'ltcbull'},
#  {'id': '3x-long-maker-token',
#   'name': '3X Long Maker Token',
#   'symbol': 'mkrbull'},
#  {'id': '3x-long-matic-token',
#   'name': '3X Long Matic Token',
#   'symbol': 'maticbull'},
#  {'id': '3x-long-midcap-index-token',
#   'name': '3X Long Midcap Index Token',
#   'symbol': 'midbull'},
#  {'id': '3x-long-okb-token', 'name': '3X Long OKB Token', 'symbol': 'okbbull'},
#  {'id': '3x-long-pax-gold-token',
#   'name': '3X Long PAX Gold Token',
#   'symbol': 'paxgbull'},
#  {'id': '3x-long-privacy-index-token',
#   'name': '3X Long Privacy Index Token',
#   'symbol': 'privbull'},
#  {'id': '3x-long-shitcoin-index-token',
#   'name': '3X Long Shitcoin Index Token',
#   'symbol': 'bullshit'},
#  {'id': '3x-long-stellar-token',
#   'name': '3X Long Stellar Token',
#   'symbol': 'xlmbull'},
#  {'id': '3x-long-sushi-token',
#   'name': '3X Long Sushi Token',
#   'symbol': 'sushibull'},
#  {'id': '3x-long-swipe-token',
#   'name': '3X Long Swipe Token',
#   'symbol': 'sxpbull'},
#  {'id': '3x-long-tether-gold-token',
#   'name': '3X Long Tether Gold Token',
#   'symbol': 'xautbull'},
#  {'id': '3x-long-tether-token',
#   'name': '3X Long Tether Token',
#   'symbol': 'usdtbull'},
#  {'id': '3x-long-tezos-token',
#   'name': '3X Long Tezos Token',
#   'symbol': 'xtzbull'},
#  {'id': '3x-long-theta-network-token',
#   'name': '3X Long Theta Network Token',
#   'symbol': 'thetabull'},
#  {'id': '3x-long-tomochain-token',
#   'name': '3X Long TomoChain Token',
#   'symbol': 'tomobull'},
#  {'id': '3x-long-trx-token', 'name': '3X Long TRX Token', 'symbol': 'trxbull'},
#  {'id': '3x-long-vechain-token',
#   'name': '3X Long VeChain Token',
#   'symbol': 'vetbull'},
#  {'id': '3x-long-xrp-token', 'name': '3X Long XRP Token', 'symbol': 'xrpbull'},
#  {'id': '3x-long-zcash-token',
#   'name': '3X Long Zcash Token',
#   'symbol': 'zecbull'},
#  {'id': '3x-short-altcoin-index-token',
#   'name': '3X Short Altcoin Index Token',
#   'symbol': 'altbear'},
#  {'id': '3x-short-balancer-token',
#   'name': '3X Short Balancer Token',
#   'symbol': 'balbear'},
#  {'id': '3x-short-bilira-token',
#   'name': '3X Short BiLira Token',
#   'symbol': 'trybbear'},
#  {'id': '3x-short-bitcoin-cash-token',
#   'name': '3X Short Bitcoin Cash Token',
#   'symbol': 'bchbear'},
#  {'id': '3x-short-bitcoin-sv-token',
#   'name': '3X Short Bitcoin SV Token',
#   'symbol': 'bsvbear'},
#  {'id': '3x-short-bitcoin-token',
#   'name': '3X Short Bitcoin Token',
#   'symbol': 'bear'},
#  {'id': '3x-short-bnb-token',
#   'name': '3X Short BNB Token',
#   'symbol': 'bnbbear'},
#  {'id': '3x-short-cardano-token',
#   'name': '3X Short Cardano Token',
#   'symbol': 'adabear'},
#  {'id': '3x-short-chainlink-token',
#   'name': '3X Short Chainlink Token',
#   'symbol': 'linkbear'},
#  {'id': '3x-short-compound-token-token',
#   'name': '3X Short Compound Token Token',
#   'symbol': 'compbear'},
#  {'id': '3x-short-compound-usdt-token',
#   'name': '3X Short Compound USDT Token',
#   'symbol': 'cusdtbear'},
#  {'id': '3x-short-cosmos-token',
#   'name': '3X Short Cosmos Token',
#   'symbol': 'atombear'},
#  {'id': '3x-short-defi-index-token',
#   'name': '3X Short DeFi Index Token',
#   'symbol': 'defibear'},
#  {'id': '3x-short-dragon-index-token',
#   'name': '3X Short Dragon Index Token',
#   'symbol': 'drgnbear'},
#  {'id': '3x-short-eos-token',
#   'name': '3X Short EOS Token',
#   'symbol': 'eosbear'},
#  {'id': '3x-short-ethereum-classic-token',
#   'name': '3X Short Ethereum Classic Token',
#   'symbol': 'etcbear'},
#  {'id': '3x-short-ethereum-token',
#   'name': '3X Short Ethereum Token',
#   'symbol': 'ethbear'},
#  {'id': '3x-short-exchange-token-index-token',
#   'name': '3X Short Exchange Token Index Token',
#   'symbol': 'exchbear'},
#  {'id': '3x-short-huobi-token-token',
#   'name': '3X Short Huobi Token Token',
#   'symbol': 'htbear'},
#  {'id': '3x-short-kyber-network-token',
#   'name': '3X Short Kyber Network Token',
#   'symbol': 'kncbear'},
#  {'id': '3x-short-leo-token',
#   'name': '3X Short LEO Token',
#   'symbol': 'leobear'},
#  {'id': '3x-short-litecoin-token',
#   'name': '3X Short Litecoin Token',
#   'symbol': 'ltcbear'},
#  {'id': '3x-short-maker-token',
#   'name': '3X Short Maker Token',
#   'symbol': 'mkrbear'},
#  {'id': '3x-short-midcap-index-token',
#   'name': '3X Short Midcap Index Token',
#   'symbol': 'midbear'},
#  {'id': '3x-short-okb-token',
#   'name': '3X Short OKB Token',
#   'symbol': 'okbbear'},
#  {'id': '3x-short-pax-gold-token',
#   'name': '3X Short PAX Gold Token',
#   'symbol': 'paxgbear'},
#  {'id': '3x-short-privacy-index-token',
#   'name': '3X Short Privacy Index Token',
#   'symbol': 'privbear'},
#  {'id': '3x-short-shitcoin-index-token',
#   'name': '3X Short Shitcoin Index Token',
#   'symbol': 'bearshit'},
#  {'id': '3x-short-stellar-token',
#   'name': '3X Short Stellar Token',
#   'symbol': 'xlmbear'},
#  {'id': '3x-short-sushi-token',
#   'name': '3X Short Sushi Token',
#   'symbol': 'sushibear'},
#  {'id': '3x-short-swipe-token',
#   'name': '3X Short Swipe Token',
#   'symbol': 'sxpbear'},
#  {'id': '3x-short-tether-gold-token',
#   'name': '3X Short Tether Gold Token',
#   'symbol': 'xautbear'},
#  {'id': '3x-short-tether-token',
#   'name': '3X Short Tether Token',
#   'symbol': 'usdtbear'},
#  {'id': '3x-short-tezos-token',
#   'name': '3X Short Tezos Token',
#   'symbol': 'xtzbear'},
#  {'id': '3x-short-theta-network-token',
#   'name': '3X Short Theta Network Token',
#   'symbol': 'thetabear'},
#  {'id': '3x-short-trx-token',
#   'name': '3X Short TRX Token',
#   'symbol': 'trxbear'},
#  {'id': '3x-short-vechain-token',
#   'name': '3X Short VeChain Token',
#   'symbol': 'vetbear'},
#  {'id': '3x-short-xrp-token',
#   'name': '3X Short XRP Token',
#   'symbol': 'xrpbear'},
#  {'id': '402-s-kostner',
#   'name': 'RealT Token - 402 S Kostner Ave, Chicago, IL 60624',
#   'symbol': 'realtoken-s-402-s.kostner-ave-chicago-il'},
#  {'id': '404', 'name': '404', 'symbol': '404'},
#  {'id': '4061-grand',
#   'name': 'RealT Token - 4061 Grand St, Detroit, MI 48238',
#   'symbol': 'realtoken-s-4061-grand-st-detroit-mi'},
#  {'id': '42-coin', 'name': '42-coin', 'symbol': '42'},
#  {'id': '4340-east-71',
#   'name': 'RealT Token - 4340 East 71, Cleveland, OH 44105',
#   'symbol': 'realtoken-s-4340-east-71-cleveland-oh'},
#  {'id': '4380-beaconsfield',
#   'name': 'RealT Token - 4380 Beaconsfield St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-4380-beaconsfield-st-detroit-mi'},
#  {'id': '451pcbcom', 'name': '451PCBcom', 'symbol': 'pcb'},
#  {'id': '4680-buckingham',
#   'name': 'RealT Token - 4680 Buckingham Ave, Detroit, MI 48224',
#   'symbol': 'realtoken-s-4680-buckingham-ave-detroit-mi'},
#  {'id': '4852-4854-w-cortez',
#   'name': 'RealT Token - 4852-4854 W Cortez St, Chicago, IL 60651',
#   'symbol': 'realtoken-s-4852-4854-w.cortez-st-chicago-il'},
#  {'id': '4artechnologies', 'name': '4ART Coin', 'symbol': '4art'},
#  {'id': '4bulls', 'name': '4Bulls', 'symbol': '4b'},
#  {'id': '4jnet', 'name': '4JNET', 'symbol': '4jnet'},
#  {'id': '4new', 'name': '4New', 'symbol': 'kwatt'},
#  {'id': '4-stock', 'name': '4-Stock', 'symbol': '4stc'},
#  {'id': '50cent', 'name': '50Cent', 'symbol': '50c'},
#  {'id': '50k', 'name': '50 Keeper', 'symbol': '50k'},
#  {'id': '520', 'name': '520', 'symbol': '520'},
#  {'id': '5601-s-wood',
#   'name': 'RealT Token - 5601 S Wood St, Chicago, IL 60636',
#   'symbol': 'realtoken-s-5601-s.wood-st-chicago-il'},
#  {'id': '581-587-jefferson',
#   'name': 'RealT Token - 581-587 Jefferson Ave, Rochester, NY 14611',
#   'symbol': 'realtoken-s-581-587-jefferson-ave-rochester-ny'},
#  {'id': '5942-audubon',
#   'name': 'RealT Token - 5942 Audubon Rd, Detroit, MI 48224',
#   'symbol': 'realtoken-s-5942-audubon-rd-detroit-mi'},
#  {'id': '5g-cash', 'name': '5G-CASH', 'symbol': 'vgc'},
#  {'id': '6923-greenview',
#   'name': 'RealT Token - 6923 Greenview Ave, Detroit, MI 48228',
#   'symbol': 'realtoken-s-6923-greenview-ave-detroit-mi'},
#  {'id': '6ix9ine-chain', 'name': '6ix9ine Chain', 'symbol': '69c'},
#  {'id': '7eleven', 'name': '7ELEVEN', 'symbol': '7e'},
#  {'id': '7plus-coin', 'name': '7Plus Coin', 'symbol': 'sv7'},
#  {'id': '7up', 'name': '7up', 'symbol': '7up'},
#  {'id': '808ta-token', 'name': '808TA Token', 'symbol': '808ta'},
#  {'id': '8181-bliss',
#   'name': 'RealT Token - 8181 Bliss St, Detroit, MI 48234',
#   'symbol': 'realtoken-s-8181-bliss-st-detroit-mi'},
#  {'id': '8342-schaefer',
#   'name': 'RealT Token - 8342 Schaefer Highway, Detroit, MI 48228',
#   'symbol': 'realtoken-s-8342-schaefer-highway-detroit-mi'},
#  {'id': '867', 'name': '867', 'symbol': '867'},
#  {'id': '888-infinity', 'name': '888 Infinity', 'symbol': '888'},
#  {'id': '888tron', 'name': '888tron', 'symbol': '888'},
#  {'id': '88mph', 'name': '88mph', 'symbol': 'mph'},
#  {'id': '8ball-finance', 'name': '8Ball Finance', 'symbol': '8ball'},
#  {'id': '8bit-doge', 'name': '8Bit Doge', 'symbol': 'bitd'},
#  {'id': '8ight-finance', 'name': '8ight Finance', 'symbol': 'eight'},
#  {'id': '8pay', 'name': '8Pay', 'symbol': '8pay'},
#  {'id': '8x8-protocol', 'name': '8X8 Protocol', 'symbol': 'exe'},
#  {'id': '9133-devonshire',
#   'name': 'RealT Token - 9133 Devonshire Rd, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9133-devonshire-rd-detroit-mi'},
#  {'id': '9165-kensington',
#   'name': 'RealT Token - 9165 Kensington Ave, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9165-kensington-ave-detroit-mi'},
#  {'id': '9166-devonshire',
#   'name': 'RealT Token - 9166 Devonshire Rd, Detroit MI 48224',
#   'symbol': 'realtoken-s-9166-devonshire-rd-detroit-mi'},
#  {'id': '9169-boleyn',
#   'name': 'RealT Token - 9169 Boleyn St, Detroit, MI, 48224',
#   'symbol': 'realtoken-s-9169-boleyn-st-detroit-mi'},
#  {'id': '9309-courville',
#   'name': 'RealT Token - 9309 Courville St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9309-courville-st-detroit-mi'},
#  {'id': '9336-patton',
#   'name': 'RealT Token - 9336 Patton St, Detroit, MI 48228',
#   'symbol': 'realtoken-s-9336-patton-st-detroit-mi'},
#  {'id': '9465-beaconsfield',
#   'name': 'RealT Token - 9465 Beaconsfield St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9465-beaconsfield-st-detroit-mi'},
#  {'id': '9481-wayburn',
#   'name': 'RealT Token - 9481 Wayburn St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9481-wayburn-st-detroit-mi'},
#  {'id': '9717-everts',
#   'name': 'RealT Token - 9717 Everts St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9717-everts-st-detroit-mi'},
#  {'id': '9920-bishop',
#   'name': 'RealT Token - 9920 Bishop St, Detroit, MI 48224',
#   'symbol': 'realtoken-s-9920-bishop-st-detroit-mi'},
#  {'id': '9943-marlowe',
#   'name': 'RealT Token - 9943 Marlowe St, Detroit, MI 48227',
#   'symbol': 'realtoken-s-9943-marlowe-st-detroit-mi'},
#  {'id': '99starz', 'name': '99Starz', 'symbol': 'stz'},
#  {'id': 'a4-finance', 'name': 'A4 Finance', 'symbol': 'a4'},
#  {'id': 'aaa-coin', 'name': 'AAA COIN', 'symbol': 'aaa'},
#  {'id': 'aag-ventures', 'name': 'AAG Ventures', 'symbol': 'aag'},
#  {'id': 'aang-inu', 'name': 'Aang Inu', 'symbol': 'aang'},
#  {'id': 'aave', 'name': 'Aave', 'symbol': 'aave'},
#  {'id': 'aave-aave', 'name': 'Aave AAVE', 'symbol': 'aAAVE'},
#  {'id': 'aave-amm-bptbalweth',
#   'name': 'Aave AMM BptBALWETH',
#   'symbol': 'aAmmBptBALWETH'},
#  {'id': 'aave-amm-bptwbtcweth',
#   'name': 'Aave AMM BptWBTCWETH',
#   'symbol': 'aAmmBptWBTCWETH'},
#  {'id': 'aave-amm-dai', 'name': 'Aave AMM DAI', 'symbol': 'aAmmDAI'},
#  {'id': 'aave-amm-uniaaveweth',
#   'name': 'Aave AMM UniAAVEWETH',
#   'symbol': 'aammuniaaveweth'},
#  {'id': 'aave-amm-unibatweth',
#   'name': 'Aave AMM UniBATWETH',
#   'symbol': 'aAmmUniBATWETH'},
#  {'id': 'aave-amm-unicrvweth',
#   'name': 'Aave AMM UniCRVWETH',
#   'symbol': 'aAmmUniCRVWETH'},
#  {'id': 'aave-amm-unidaiusdc',
#   'name': 'Aave AMM UniDAIUSDC',
#   'symbol': 'aAmmUniDAIUSDC'},
#  {'id': 'aave-amm-unidaiweth',
#   'name': 'Aave AMM UniDAIWETH',
#   'symbol': 'aammunidaiweth'},
#  {'id': 'aave-amm-unilinkweth',
#   'name': 'Aave AMM UniLINKWETH',
#   'symbol': 'aAmmUniLINKWETH'},
#  {'id': 'aave-amm-unimkrweth',
#   'name': 'Aave AMM UniMKRWETH',
#   'symbol': 'aAmmUniMKRWETH'},
#  {'id': 'aave-amm-unirenweth',
#   'name': 'Aave AMM UniRENWETH',
#   'symbol': 'aAmmUniRENWETH'},
#  {'id': 'aave-amm-unisnxweth',
#   'name': 'Aave AMM UniSNXWETH',
#   'symbol': 'aAmmUniSNXWETH'},
#  {'id': 'aave-amm-uniuniweth',
#   'name': 'Aave AMM UniUNIWETH',
#   'symbol': 'aAmmUniUNIWETH'},
#  {'id': 'aave-amm-uniusdcweth',
#   'name': 'Aave AMM UniUSDCWETH',
#   'symbol': 'aAmmUniUSDCWETH'},
#  {'id': 'aave-amm-uniwbtcusdc',
#   'name': 'Aave AMM UniWBTCUSDC',
#   'symbol': 'aAmmUniWBTCUSDC'},
#  {'id': 'aave-amm-uniwbtcweth',
#   'name': 'Aave AMM UniWBTCWETH',
#   'symbol': 'aammuniwbtcweth'},
#  {'id': 'aave-amm-uniyfiweth',
#   'name': 'Aave AMM UniYFIWETH',
#   'symbol': 'aAmmUniYFIWETH'},
#  {'id': 'aave-amm-usdc', 'name': 'Aave AMM USDC', 'symbol': 'aAmmUSDC'},
#  {'id': 'aave-amm-usdt', 'name': 'Aave AMM USDT', 'symbol': 'aAmmUSDT'},
#  {'id': 'aave-amm-wbtc', 'name': 'Aave AMM WBTC', 'symbol': 'aAmmWBTC'},
#  {'id': 'aave-amm-weth', 'name': 'Aave AMM WETH', 'symbol': 'aAmmWETH'},
#  {'id': 'aave-bal', 'name': 'Aave BAL', 'symbol': 'abal'},
#  {'id': 'aave-balancer-pool-token',
#   'name': 'Aave Balancer Pool Token',
#   'symbol': 'abpt'},
#  {'id': 'aave-bat', 'name': 'Aave BAT', 'symbol': 'abat'},
#  {'id': 'aave-bat-v1', 'name': 'Aave BAT v1', 'symbol': 'abat'},
#  {'id': 'aave-busd', 'name': 'Aave BUSD', 'symbol': 'abusd'},
#  {'id': 'aave-busd-v1', 'name': 'Aave BUSD v1', 'symbol': 'abusd'},
#  {'id': 'aave-crv', 'name': 'Aave CRV', 'symbol': 'aCRV'},
#  {'id': 'aave-dai', 'name': 'Aave DAI', 'symbol': 'adai'},
#  {'id': 'aave-dai-v1', 'name': 'Aave DAI v1', 'symbol': 'adai'},
#  {'id': 'aave-enj', 'name': 'Aave ENJ', 'symbol': 'aenj'},
#  {'id': 'aave-enj-v1', 'name': 'Aave ENJ v1', 'symbol': 'aenj'},
#  {'id': 'aave-eth-v1', 'name': 'Aave ETH v1', 'symbol': 'aeth'},
#  {'id': 'aavegotchi', 'name': 'Aavegotchi', 'symbol': 'ghst'},
#  {'id': 'aave-gusd', 'name': 'Aave GUSD', 'symbol': 'agusd'},
#  {'id': 'aave-interest-bearing-ampl',
#   'name': 'Aave interest bearing AMPL',
#   'symbol': 'aampl'},
#  {'id': 'aave-knc', 'name': 'Aave KNC', 'symbol': 'aknc'},
#  {'id': 'aave-knc-v1', 'name': 'Aave KNC v1', 'symbol': 'aknc'},
#  {'id': 'aave-link', 'name': 'Aave LINK', 'symbol': 'alink'},
#  {'id': 'aave-link-v1', 'name': 'Aave LINK v1', 'symbol': 'alink'},
#  {'id': 'aave-mana', 'name': 'Aave MANA', 'symbol': 'amana'},
#  {'id': 'aave-mana-v1', 'name': 'Aave MANA v1', 'symbol': 'amana'},
#  {'id': 'aave-mkr', 'name': 'Aave MKR', 'symbol': 'amkr'},
#  {'id': 'aave-mkr-v1', 'name': 'Aave MKR v1', 'symbol': 'amkr'},
#  {'id': 'aave-polygon-aave', 'name': 'Aave Polygon AAVE', 'symbol': 'amAAVE'},
#  {'id': 'aave-polygon-dai', 'name': 'Aave Polygon DAI', 'symbol': 'amDAI'},
#  {'id': 'aave-polygon-usdc', 'name': 'Aave Polygon USDC', 'symbol': 'amusdc'},
#  {'id': 'aave-polygon-usdt', 'name': 'Aave Polygon USDT', 'symbol': 'amUSDT'},
#  {'id': 'aave-polygon-wbtc', 'name': 'Aave Polygon WBTC', 'symbol': 'amWBTC'},
#  {'id': 'aave-polygon-weth', 'name': 'Aave Polygon WETH', 'symbol': 'amWETH'},
#  {'id': 'aave-polygon-wmatic',
#   'name': 'Aave Polygon WMATIC',
#   'symbol': 'amWMATIC'},
#  {'id': 'aave-rai', 'name': 'Aave RAI', 'symbol': 'arai'},
#  {'id': 'aave-ren', 'name': 'Aave REN', 'symbol': 'aren'},
#  {'id': 'aave-ren-v1', 'name': 'Aave REN v1', 'symbol': 'aren'},
#  {'id': 'aave-snx', 'name': 'Aave SNX', 'symbol': 'asnx'},
#  {'id': 'aave-snx-v1', 'name': 'Aave SNX v1', 'symbol': 'asnx'},
#  {'id': 'aave-susd', 'name': 'Aave SUSD', 'symbol': 'asusd'},
#  {'id': 'aave-susd-v1', 'name': 'Aave SUSD v1', 'symbol': 'asusd'},
#  {'id': 'aave-tusd', 'name': 'Aave TUSD', 'symbol': 'atusd'},
#  {'id': 'aave-tusd-v1', 'name': 'Aave TUSD v1', 'symbol': 'atusd'},
#  {'id': 'aave-uni', 'name': 'Aave UNI', 'symbol': 'auni'},
#  {'id': 'aave-usdc', 'name': 'Aave USDC', 'symbol': 'ausdc'},
#  {'id': 'aave-usdc-v1', 'name': 'Aave USDC v1', 'symbol': 'ausdc'},
#  {'id': 'aave-usdt', 'name': 'Aave USDT', 'symbol': 'ausdt'},
#  {'id': 'aave-usdt-v1', 'name': 'Aave USDT v1', 'symbol': 'ausdt'},
#  {'id': 'aave-wbtc', 'name': 'Aave WBTC', 'symbol': 'awbtc'},
#  {'id': 'aave-wbtc-v1', 'name': 'Aave WBTC v1', 'symbol': 'awbtc'},
#  {'id': 'aave-weth', 'name': 'Aave WETH', 'symbol': 'aweth'},
#  {'id': 'aave-xsushi', 'name': 'Aave XSUSHI', 'symbol': 'aXSUSHI'},
#  {'id': 'aave-yfi', 'name': 'Aave YFI', 'symbol': 'aYFI'},
#  {'id': 'aave-zrx', 'name': 'Aave ZRX', 'symbol': 'azrx'},
#  {'id': 'aave-zrx-v1', 'name': 'Aave ZRX v1', 'symbol': 'azrx'},
#  {'id': 'aax-token', 'name': 'AAX Token', 'symbol': 'aab'},
#  {'id': 'abachi', 'name': 'Abachi', 'symbol': 'abi'},
#  {'id': 'abc-chain', 'name': 'ABC Chain', 'symbol': 'abc'},
#  {'id': 'abcc-token', 'name': 'ABCC Token', 'symbol': 'at'},
#  {'id': 'abcd-token', 'name': 'ABCD Token', 'symbol': 'abcd'},
#  {'id': 'abell-coin', 'name': 'Abell Coin', 'symbol': 'abc'},
#  {'id': 'abey', 'name': 'Abey', 'symbol': 'abey'},
#  {'id': 'abitshadow-token', 'name': 'Abitshadow Token', 'symbol': 'abst'},
#  {'id': 'able-finance', 'name': 'Able Finance', 'symbol': 'able'},
#  {'id': 'absolute', 'name': 'Absolute', 'symbol': 'abs'},
#  {'id': 'absorber', 'name': 'Absorber', 'symbol': 'abs'},
#  {'id': 'abulaba', 'name': 'Abulaba', 'symbol': 'aaa'},
#  {'id': 'abura-farm', 'name': 'Abura Farm', 'symbol': 'abu'},
#  {'id': 'acala-token', 'name': 'Acala Token', 'symbol': 'aca'},
#  {'id': 'acash-coin', 'name': 'Acash Coin', 'symbol': 'aca'},
#  {'id': 'aca-token', 'name': 'ACA Token', 'symbol': 'aca'},
#  {'id': 'accel-defi', 'name': 'Accel Defi', 'symbol': 'accel'},
#  {'id': 'accesslauncher', 'name': 'AccessLauncher', 'symbol': 'acx'},
#  {'id': 'ace-casino', 'name': 'Ace Entertainment', 'symbol': 'ace'},
#  {'id': 'aced', 'name': 'Aced [OLD]', 'symbol': 'aced'},
#  {'id': 'aced-2', 'name': 'Aced', 'symbol': 'aced'},
#  {'id': 'acent', 'name': 'Acent', 'symbol': 'ace'},
#  {'id': 'acet-token', 'name': 'Acet', 'symbol': 'act'},
#  {'id': 'ac-exchange-token', 'name': 'ACDX Exchange Token', 'symbol': 'acxt'},
#  {'id': 'achain', 'name': 'Achain', 'symbol': 'act'},
#  {'id': 'acknoledger', 'name': 'AcknoLedger', 'symbol': 'ack'},
#  {'id': 'ac-milan-fan-token', 'name': 'AC Milan Fan Token', 'symbol': 'acm'},
#  {'id': 'acoconut', 'name': 'ACoconut', 'symbol': 'ac'},
#  {'id': 'acoin', 'name': 'Acoin', 'symbol': 'acoin'},
#  {'id': 'acreage-coin', 'name': 'Acreage Coin', 'symbol': 'acr'},
#  {'id': 'acryl', 'name': 'Acryl', 'symbol': 'acryl'},
#  {'id': 'acryptos', 'name': 'ACryptoS', 'symbol': 'acs'},
#  {'id': 'acryptosi', 'name': 'ACryptoSI', 'symbol': 'acsi'},
#  {'id': 'actinium', 'name': 'Actinium', 'symbol': 'acm'},
#  {'id': 'action-coin', 'name': 'Action Coin', 'symbol': 'actn'},
#  {'id': 'activada', 'name': 'ActivADA', 'symbol': 'ACADA'},
#  {'id': 'acuity-token', 'name': 'Acuity', 'symbol': 'acu'},
#  {'id': 'acu-platform', 'name': 'ACU Platform', 'symbol': 'acu'},
#  {'id': 'acute-angle-cloud', 'name': 'Acute Angle Cloud', 'symbol': 'aac'},
#  {'id': 'acy-finance', 'name': 'ACY Finance', 'symbol': 'acy'},
#  {'id': 'adaboy', 'name': 'ADABoy', 'symbol': 'adaboy'},
#  {'id': 'adacash', 'name': 'ADAcash', 'symbol': 'adacash'},
#  {'id': 'adadex-tools', 'name': 'Adadex Tools', 'symbol': 'adat'},
#  {'id': 'adaflect', 'name': 'ADAFlect', 'symbol': 'ADAFlect'},
#  {'id': 'adakong', 'name': 'AdaKong', 'symbol': 'akong'},
#  {'id': 'adamant', 'name': 'Adamant', 'symbol': 'addy'},
#  {'id': 'adamant-coin', 'name': 'Adamant Coin', 'symbol': 'admc'},
#  {'id': 'adamant-messenger', 'name': 'ADAMANT Messenger', 'symbol': 'adm'},
#  {'id': 'adana-demirspor', 'name': 'Adana Demirspor', 'symbol': 'demir'},
#  {'id': 'adapad', 'name': 'ADAPad', 'symbol': 'adapad'},
#  {'id': 'adappter-token', 'name': 'Adappter Token', 'symbol': 'adp'},
#  {'id': 'adax', 'name': 'ADAX', 'symbol': 'adax'},
#  {'id': 'adbank', 'name': 'adbank', 'symbol': 'adb'},
#  {'id': 'addax', 'name': 'Addax', 'symbol': 'adx'},
#  {'id': 'addict-finance', 'name': 'Addict Finance', 'symbol': 'addict'},
#  {'id': 'add-xyz-new', 'name': 'Add.xyz (NEW)', 'symbol': 'add'},
#  {'id': 'adelphoi', 'name': 'Adelphoi', 'symbol': 'adl'},
#  {'id': 'adena-finance', 'name': 'Adena Finance', 'symbol': 'adena'},
#  {'id': 'adene', 'name': 'Adene', 'symbol': 'ADEN'},
#  {'id': 'adex', 'name': 'Ambire AdEx', 'symbol': 'adx'},
#  {'id': 'ad-flex-token', 'name': 'Ad Flex Token', 'symbol': 'adf'},
#  {'id': 'aditus', 'name': 'Aditus', 'symbol': 'adi'},
#  {'id': 'admonkey', 'name': 'AdMonkey', 'symbol': 'admonkey'},
#  {'id': 'adora-token', 'name': 'Adora Token', 'symbol': 'ara'},
#  {'id': 'adshares', 'name': 'Adshares', 'symbol': 'ads'},
#  {'id': 'adtoken', 'name': 'adToken', 'symbol': 'adt'},
#  {'id': 'advanced-internet-block',
#   'name': 'Advanced Integrated Blocks',
#   'symbol': 'aib'},
#  {'id': 'advar-protocol', 'name': 'Advar Protocol', 'symbol': 'advar'},
#  {'id': 'adventure-gold', 'name': 'Adventure Gold', 'symbol': 'agld'},
#  {'id': 'adventure-inu', 'name': 'Adventure Inu', 'symbol': 'adinu'},
#  {'id': 'adventure-token', 'name': 'Adventure Token', 'symbol': 'twa'},
#  {'id': 'advertise-coin', 'name': 'Advertise Coin', 'symbol': 'adco'},
#  {'id': 'aegis', 'name': 'Aegis', 'symbol': 'ags'},
#  {'id': 'aegis-launchpad', 'name': 'Aegis Launchpad', 'symbol': 'agspad'},
#  {'id': 'aelf', 'name': 'aelf', 'symbol': 'elf'},
#  {'id': 'aelin', 'name': 'Aelin', 'symbol': 'aelin'},
#  {'id': 'aelysir', 'name': 'Aelysir', 'symbol': 'ael'},
#  {'id': 'aeneas', 'name': 'Aeneas', 'symbol': 'ash'},
#  {'id': 'aen-smart-token', 'name': 'AEN Smart Token', 'symbol': 'aens'},
#  {'id': 'aeon', 'name': 'Aeon', 'symbol': 'aeon'},
#  {'id': 'aerdrop', 'name': 'Aerdrop', 'symbol': 'aer'},
#  {'id': 'aergo', 'name': 'Aergo', 'symbol': 'aergo'},
#  {'id': 'aeron', 'name': 'Aeron', 'symbol': 'arnx'},
#  {'id': 'aerotoken', 'name': 'AEROTOKEN', 'symbol': 'aet'},
#  {'id': 'aerotyne', 'name': 'Aerotyne', 'symbol': 'atyne'},
#  {'id': 'aeryus', 'name': 'Aeryus', 'symbol': 'aer'},
#  {'id': 'aeternity', 'name': 'Aeternity', 'symbol': 'ae'},
#  {'id': 'aetherius', 'name': 'Aetherius', 'symbol': 'aeth'},
#  {'id': 'aetherv2', 'name': 'AetherV2', 'symbol': 'ATH'},
#  {'id': 'aeur', 'name': 'AEUR', 'symbol': 'aeur'},
#  {'id': 'aevolve-token', 'name': 'Aevolve Token', 'symbol': 'avex!'},
#  {'id': 'aezora', 'name': 'Aezora', 'symbol': 'azr'},
#  {'id': 'afen-blockchain', 'name': 'AFEN Blockchain', 'symbol': 'afen'},
#  {'id': 'afin-coin', 'name': 'Asian Fintech', 'symbol': 'afin'},
#  {'id': 'afreum', 'name': 'Afreum', 'symbol': 'afr'},
#  {'id': 'africa-trading-chain',
#   'name': 'Africa Trading Chain',
#   'symbol': 'att'},
#  {'id': 'afrix', 'name': 'Afrix', 'symbol': 'afx'},
#  {'id': 'afro', 'name': 'Afro', 'symbol': 'afro'},
#  {'id': 'afrodex', 'name': 'AfroDex', 'symbol': 'afrox'},
#  {'id': 'afrodex-labs-token', 'name': 'AfroDex Labs Token', 'symbol': 'afdlt'},
#  {'id': 'afrostar', 'name': 'Afrostar', 'symbol': 'afro'},
#  {'id': 'afterback', 'name': 'AfterBack', 'symbol': 'aftrbck'},
#  {'id': 'afterburn', 'name': 'AfterBurn', 'symbol': 'aftrbrn'},
#  {'id': 'aga-carbon-credit', 'name': 'AGA Carbon Credit', 'symbol': 'agac'},
#  {'id': 'aga-carbon-rewards', 'name': 'AGA Carbon Rewards', 'symbol': 'acar'},
#  {'id': 'again-project', 'name': 'Again Project', 'symbol': 'again'},
#  {'id': 'aga-rewards', 'name': 'Edcoin', 'symbol': 'edc'},
#  {'id': 'aga-rewards-2', 'name': 'AGA Rewards', 'symbol': 'agar'},
#  {'id': 'aga-token', 'name': 'AGA Token', 'symbol': 'aga'},
#  {'id': 'agavecoin', 'name': 'AgaveCoin', 'symbol': 'agvc'},
#  {'id': 'agave-token', 'name': 'Agave Token', 'symbol': 'agve'},
#  {'id': 'agenor', 'name': 'Agenor', 'symbol': 'age'},
#  {'id': 'agent-shiba-inu',
#   'name': 'Agent Shiba I.N.U.',
#   'symbol': 'agentshibainu'},
#  {'id': 'ageofgods', 'name': 'AgeOfGods', 'symbol': 'aog'},
#  {'id': 'age-of-knights', 'name': 'Age Of Knights', 'symbol': 'gem'},
#  {'id': 'age-of-tanks', 'name': 'Age Of Tanks', 'symbol': 'a.o.t'},
#  {'id': 'ageur', 'name': 'agEUR', 'symbol': 'ageur'},
#  {'id': 'aggle-io', 'name': 'aggle.io', 'symbol': 'aggl'},
#  {'id': 'aggregatedfinance', 'name': 'AggregatedFinance', 'symbol': 'agfi'},
#  {'id': 'agile', 'name': 'Agile', 'symbol': 'agl'},
#  {'id': 'agoras-currency-of-tau',
#   'name': 'Agoras: Currency of Tau',
#   'symbol': 'agrs'},
#  {'id': 'agouti', 'name': 'Agouti', 'symbol': 'agu'},
#  {'id': 'agpc', 'name': 'AGPC', 'symbol': 'agpc'},
#  {'id': 'agrello', 'name': 'Agrello', 'symbol': 'dlt'},
#  {'id': 'agricoin', 'name': 'Agricoin', 'symbol': 'AGN'},
#  {'id': 'agrinoble', 'name': 'Agrinoble', 'symbol': 'agn'},
#  {'id': 'agrinovuscoin', 'name': 'AgriNovusCoin', 'symbol': 'agri'},
#  {'id': 'agrocash-x', 'name': 'AgroCash X', 'symbol': 'xagc'},
#  {'id': 'agrofarm', 'name': 'Agrofarm', 'symbol': 'farm'},
#  {'id': 'agro-global', 'name': 'Agro Global', 'symbol': 'agro'},
#  {'id': 'agrolot', 'name': 'AGROLOT', 'symbol': 'aglt'},
#  {'id': 'agro-matic', 'name': 'Agro-Matic', 'symbol': 'AMT'},
#  {'id': 'agronomist', 'name': 'Agronomist', 'symbol': 'agte'},
#  {'id': 'ahatoken', 'name': 'AhaToken', 'symbol': 'aht'},
#  {'id': 'aichain', 'name': 'AICHAIN', 'symbol': 'ait'},
#  {'id': 'aicon', 'name': 'Aicon', 'symbol': 'aico'},
#  {'id': 'aidcoin', 'name': 'AidCoin', 'symbol': 'aid'},
#  {'id': 'aidi-finance', 'name': 'Aidi Finance', 'symbol': 'aidi'},
#  {'id': 'aidi-inu', 'name': 'Aidi Inu', 'symbol': 'aidi'},
#  {'id': 'ai-doctor', 'name': 'AI Doctor', 'symbol': 'aidoc'},
#  {'id': 'aidos-kuneen', 'name': 'Aidos Kuneen', 'symbol': 'adk'},
#  {'id': 'ailink-token', 'name': 'AiLink Token', 'symbol': 'ali'},
#  {'id': 'aimedis-2', 'name': 'Aimedis', 'symbol': 'aimx'},
#  {'id': 'ai-network', 'name': 'AI Network', 'symbol': 'ain'},
#  {'id': 'ainu-token', 'name': 'Ainu Token', 'symbol': 'ainu'},
#  {'id': 'aion', 'name': 'Aion', 'symbol': 'aion'},
#  {'id': 'aioz-network', 'name': 'AIOZ Network', 'symbol': 'aioz'},
#  {'id': 'aipichain', 'name': 'AiPiChain', 'symbol': 'aipi'},
#  {'id': 'airbloc-protocol', 'name': 'Airbloc', 'symbol': 'abl'},
#  {'id': 'aircoin-2', 'name': 'AirCoin', 'symbol': 'air'},
#  {'id': 'aircoins', 'name': 'Aircoins', 'symbol': 'airx'},
#  {'id': 'airdropper', 'name': 'AirDropper', 'symbol': 'air'},
#  {'id': 'airdrop-world', 'name': 'Airdrop World', 'symbol': 'awt'},
#  {'id': 'airight', 'name': 'aiRight', 'symbol': 'airi'},
#  {'id': 'airnft-token', 'name': 'AirNFT Token', 'symbol': 'airt'},
#  {'id': 'airraid-lottery-token',
#   'name': 'AirRaid Lottery Token',
#   'symbol': 'araid'},
#  {'id': 'air-shiba', 'name': 'Air Shiba', 'symbol': 'AIRSHIB'},
#  {'id': 'airswap', 'name': 'AirSwap', 'symbol': 'ast'},
#  {'id': 'aisf', 'name': 'AISF', 'symbol': 'agt'},
#  {'id': 'ai-tech', 'name': 'Ai-Tech', 'symbol': 'ai-tech'},
#  {'id': 'aitra', 'name': 'AITRA', 'symbol': 'aitra'},
#  {'id': 'aiwork', 'name': 'AiWork', 'symbol': 'awo'},
#  {'id': 'ajeverse', 'name': 'Ajeverse', 'symbol': 'aje'},
#  {'id': 'akamaru-inu', 'name': 'Akamaru Inu', 'symbol': 'akamaru'},
#  {'id': 'akash-network', 'name': 'Akash Network', 'symbol': 'akt'},
# ...
#  {'id': 'apebullinu', 'name': 'ApeBullInu', 'symbol': 'abi'},
#  {'id': 'apebusd', 'name': 'ApeBUSD', 'symbol': 'apebusd'},
#  {'id': 'apecoin', 'name': 'APEcoin', 'symbol': 'ape'},
#  {'id': 'apefarmer', 'name': 'ApeFarmer', 'symbol': 'apef'},
#  {'id': 'apefund', 'name': 'ApeFund', 'symbol': 'apefund'},
#  {'id': 'ape-fun-token', 'name': 'Ape Fun Token', 'symbol': 'aft'},
#  {'id': 'apehaven', 'name': 'ApeHaven', 'symbol': 'apes'},
#  {'id': 'ape-in', 'name': 'Ape In', 'symbol': 'apein'},
#  {'id': 'apelab', 'name': 'ApeLab', 'symbol': 'ape'},
#  {'id': 'apenft', 'name': 'APENFT', 'symbol': 'nft'},
#  {'id': 'ape-punk', 'name': 'APE Punk', 'symbol': 'ape$'},
#  {'id': 'apes-of-empires', 'name': 'Apes of Empires', 'symbol': 'aoe'},
#  {'id': 'apes-token', 'name': 'Apes Token', 'symbol': 'apes'},
#  {'id': 'apeswap-finance', 'name': 'ApeSwap Finance', 'symbol': 'banana'},
#  {'id': 'apetoken', 'name': 'APEToken', 'symbol': 'APET'},
#  {'id': 'ape-token', 'name': 'Ape Token', 'symbol': 'apet'},
#  {'id': 'ape-x', 'name': 'Ape-X', 'symbol': 'ape-x'},
#  {'id': 'apex-army', 'name': 'APEx Army', 'symbol': 'apex'},
#  {'id': 'apexit-finance', 'name': 'ApeXit Finance', 'symbol': 'apex'},
#  {'id': 'apex-protocol', 'name': 'APEX Protocol', 'symbol': 'apxp'},
#  {'id': 'apex-token', 'name': 'Apex Finance', 'symbol': 'apex'},
#  {'id': 'apholding-coin', 'name': 'APHolding Coin', 'symbol': 'aph'},
#  {'id': 'api3', 'name': 'API3', 'symbol': 'api3'},
#  {'id': 'apiary-fund-coin', 'name': 'Apiary Fund Coin', 'symbol': 'afc'},
#  {'id': 'apidai-network', 'name': 'Apidai Network', 'symbol': 'apidai'},
#  {'id': 'apix', 'name': 'APIX', 'symbol': 'apix'},
#  {'id': 'apm-coin', 'name': 'apM Coin', 'symbol': 'APM'},
#  {'id': 'apollo', 'name': 'Apollo', 'symbol': 'apl'},
#  {'id': 'apollo-coin', 'name': 'Apollo Coin', 'symbol': 'APX'},
#  {'id': 'apollo-dao', 'name': 'Apollo DAO', 'symbol': 'apollo'},
#  {'id': 'apollo-inu', 'name': 'Apollo Inu', 'symbol': 'APOLLO'},
#  {'id': 'apollon-limassol',
#   'name': 'Apollon Limassol Fan Token',
#   'symbol': 'APL'},
#  {'id': 'apollox-2', 'name': 'ApolloX', 'symbol': 'apx'},
#  {'id': 'apoyield', 'name': 'APOyield', 'symbol': 'soul'},
#  {'id': 'appa-inu', 'name': 'Appa Inu', 'symbol': 'appa'},
#  {'id': 'app-alliance-association', 'name': 'AAAchain', 'symbol': 'aaa'},
#  {'id': 'appcoins', 'name': 'AppCoins', 'symbol': 'appc'},
#  {'id': 'appics', 'name': 'Appics', 'symbol': 'apx'},
#  {'id': 'apple', 'name': 'Apple', 'symbol': 'apple'},
#  {'id': 'apple-finance', 'name': 'Apple Finance', 'symbol': 'aplp'},
#  {'id': 'apple-network', 'name': 'Apple Network', 'symbol': 'ank'},
#  {'id': 'apple-protocol-token',
#   'name': 'Apple Protocol Token',
#   'symbol': 'aapl'},
#  {'id': 'appleswap', 'name': 'AppleSwap', 'symbol': 'apple'},
#  {'id': 'apr-coin', 'name': 'APR Coin', 'symbol': 'apr'},
#  {'id': 'apricot', 'name': 'Apricot', 'symbol': 'apt'},
#  {'id': 'april', 'name': 'April', 'symbol': 'april'},
#  {'id': 'apron', 'name': 'Apron', 'symbol': 'apn'},
#  {'id': 'apwine', 'name': 'APWine', 'symbol': 'apw'},
#  {'id': 'apy-finance', 'name': 'APY.Finance', 'symbol': 'apy'},
#  {'id': 'apyswap', 'name': 'APYSwap', 'symbol': 'apys'},
#  {'id': 'apy-vision', 'name': 'APY.vision', 'symbol': 'vision'},
#  {'id': 'aqar-chain', 'name': 'Aqar Chain', 'symbol': 'aqr'},
#  {'id': 'aqua', 'name': 'Aqua', 'symbol': 'aqua'},
#  {'id': 'aquachain', 'name': 'Aquachain', 'symbol': 'aqua'},
#  {'id': 'aquafi', 'name': 'AquaFi', 'symbol': 'aqua'},
#  {'id': 'aqua-goat', 'name': 'Aqua Goat', 'symbol': 'aquagoat'},
#  {'id': 'aquagoat-old', 'name': 'AquaGoat (Old)', 'symbol': 'aquagoat'},
#  {'id': 'aquari', 'name': 'Aquari', 'symbol': 'aquari'},
#  {'id': 'aquarius', 'name': 'Aquarius', 'symbol': 'aqua'},
#  {'id': 'aquariuscoin', 'name': 'AquariusCoin', 'symbol': 'arco'},
#  {'id': 'aquarius-fi', 'name': 'Aquarius.Fi', 'symbol': 'aqu'},
#  {'id': 'arabic', 'name': 'Arabic', 'symbol': 'abic'},
#  {'id': 'arabtycoon', 'name': 'ArabTycoon', 'symbol': 'at'},
#  {'id': 'aragon', 'name': 'Aragon', 'symbol': 'ant'},
#  {'id': 'arank', 'name': 'Arank', 'symbol': 'arank'},
#  {'id': 'araplanet', 'name': 'AraPlanet', 'symbol': 'arap'},
#  {'id': 'arata', 'name': 'Arata', 'symbol': 'arata'},
#  {'id': 'ara-token', 'name': 'Ara Token', 'symbol': 'ara'},
#  {'id': 'araw-token', 'name': 'ARAW Token', 'symbol': 'araw'},
#  {'id': 'arbidex', 'name': 'Arbidex', 'symbol': 'abx'},
#  {'id': 'arbidoge', 'name': 'ArbiDoge', 'symbol': 'adoge'},
#  {'id': 'arbifarm', 'name': 'ArbiFarm', 'symbol': 'AFARM'},
#  {'id': 'arbimatter', 'name': 'ArbiMATTER', 'symbol': 'arbimatter'},
#  {'id': 'arbinyan', 'name': 'ArbiNYAN', 'symbol': 'nyan'},
#  {'id': 'arbirise-finance', 'name': 'ArbiRiseFinance', 'symbol': 'arf'},
#  {'id': 'arbis-finance', 'name': 'Arbis Finance', 'symbol': 'arbis'},
#  {'id': 'arbismart-token', 'name': 'ArbiSmart Token', 'symbol': 'rbis'},
#  {'id': 'arbiswap', 'name': 'Arbiswap', 'symbol': 'aswap'},
#  {'id': 'arbiter', 'name': 'Arbiter', 'symbol': 'arb'},
#  {'id': 'arbix-finance', 'name': 'Arbix Finance', 'symbol': 'arbx'},
#  {'id': 'arbucks', 'name': 'Arbucks', 'symbol': 'buck'},
#  {'id': 'arbys', 'name': 'Arbys Token', 'symbol': 'arbys'},
#  {'id': 'arcade', 'name': 'Arcade', 'symbol': 'arc'},
#  {'id': 'arcadenetwork', 'name': 'ArcadeNetwork', 'symbol': 'arc'},
#  {'id': 'arcadium', 'name': 'Arcadium', 'symbol': 'arcadium'},
#  {'id': 'arcana', 'name': 'Arcana', 'symbol': 'ARCA'},
#  {'id': 'arcane', 'name': 'Arcane', 'symbol': 'ARCANE'},
#  {'id': 'arcaneleague', 'name': 'ArcaneLeague', 'symbol': 'arcaneleague'},
#  {'id': 'arcane-token', 'name': 'Arcane Token', 'symbol': 'arcane'},
#  {'id': 'arcanineinu', 'name': 'ArcanineInu', 'symbol': 'arcanineinu'},
#  {'id': 'arcblock', 'name': 'Arcblock', 'symbol': 'abt'},
#  {'id': 'arc-block-protocol', 'name': 'Arc Block Protocol', 'symbol': 'abp'},
#  {'id': 'arc-governance', 'name': 'ARC Governance', 'symbol': 'arcx'},
#  {'id': 'archangel-token', 'name': 'ArchAngel', 'symbol': 'archa'},
#  {'id': 'archer-dao-governance-token',
#   'name': 'Archer DAO Governance Token',
#   'symbol': 'arch'},
#  {'id': 'archethic', 'name': 'ArchEthic', 'symbol': 'uco'},
#  {'id': 'archetypal-network', 'name': 'Archetypal Network', 'symbol': 'actp'},
#  {'id': 'arcona', 'name': 'Arcona', 'symbol': 'arcona'},
#  {'id': 'arcs', 'name': 'ARCS', 'symbol': 'arx'},
#  {'id': 'arcticcoin', 'name': 'Advanced Technology Coin', 'symbol': 'arc'},
#  {'id': 'arctic-finance', 'name': 'Arctic Finance', 'symbol': 'aurora'},
#  {'id': 'ardana', 'name': 'Ardana', 'symbol': 'dana'},
#  {'id': 'ardcoin', 'name': 'ArdCoin', 'symbol': 'ardx'},
#  {'id': 'ardor', 'name': 'Ardor', 'symbol': 'ardr'},
#  {'id': 'arena-token', 'name': 'Arena Token', 'symbol': 'arena'},
#  {'id': 'ares-protocol', 'name': 'Ares Protocol', 'symbol': 'ares'},
#  {'id': 'argentine-football-association-fan-token',
#   'name': 'Argentine Football Association Fan Token',
#   'symbol': 'arg'},
#  {'id': 'argo', 'name': 'ArGoApp', 'symbol': 'argo'},
#  {'id': 'argon', 'name': 'Argon', 'symbol': 'argon'},
#  {'id': 'ari10', 'name': 'Ari10', 'symbol': 'ari10'},
#  {'id': 'ariadne', 'name': 'Ariadne', 'symbol': 'ardn'},
#  {'id': 'arianee', 'name': 'Arianee', 'symbol': 'aria20'},
#  {'id': 'aries-financial-token', 'name': 'Aries Financial', 'symbol': 'afib'},
#  {'id': 'arion', 'name': 'Arion', 'symbol': 'arion'},
#  {'id': 'arionum', 'name': 'Arionum', 'symbol': 'aro'},
#  {'id': 'arise-finance', 'name': 'Arise Finance', 'symbol': 'ari'},
#  {'id': 'ari-swap', 'name': 'Ari Swap', 'symbol': 'ari'},
#  {'id': 'ariva', 'name': 'Ariva', 'symbol': 'arv'},
#  {'id': 'arix', 'name': 'Arix', 'symbol': 'arix'},
#  {'id': 'ark', 'name': 'Ark', 'symbol': 'ark'},
#  {'id': 'arkadiko-protocol', 'name': 'Arkadiko', 'symbol': 'diko'},
#  {'id': 'arke', 'name': 'ARKE', 'symbol': 'arke'},
#  {'id': 'arker-2', 'name': 'Arker', 'symbol': 'arker'},
#  {'id': 'armada', 'name': 'Armada', 'symbol': 'ARMD'},
#  {'id': 'armor', 'name': 'ARMOR', 'symbol': 'armor'},
#  {'id': 'armor-nxm', 'name': 'Armor NXM', 'symbol': 'arnxm'},
#  {'id': 'armours', 'name': 'Armours', 'symbol': 'arm'},
#  {'id': 'armzlegends', 'name': 'ArmzLegends', 'symbol': 'prot'},
#  {'id': 'around-network', 'name': 'Around Network', 'symbol': 'art'},
#  {'id': 'arowana-token', 'name': 'Arowana Token', 'symbol': 'arw'},
#  {'id': 'arpa-chain', 'name': 'ARPA Chain', 'symbol': 'arpa'},
#  {'id': 'arqma', 'name': 'ArQmA', 'symbol': 'arq'},
#  {'id': 'arrb-token', 'name': 'Arrb Token', 'symbol': 'arrb'},
#  {'id': 'arrow', 'name': 'Arrow', 'symbol': 'arw'},
#  {'id': 'arsenal-fan-token', 'name': 'Arsenal Fan Token', 'symbol': 'AFC'},
#  {'id': 'artax', 'name': 'ARTAX', 'symbol': 'xax'},
#  {'id': 'art-blocks-curated-fidenza-855',
#   'name': 'Art Blocks Curated Fidenza #855',
#   'symbol': 'fdnza'},
#  {'id': 'art-blocks-curated-full-set',
#   'name': 'Art Blocks Curated Full Set',
#   'symbol': 'abc123'},
#  {'id': 'artbyte', 'name': 'ArtByte', 'symbol': 'aby'},
#  {'id': 'artem', 'name': 'Artem', 'symbol': 'artem'},
#  {'id': 'artemis', 'name': 'Artemis', 'symbol': 'mis'},
#  {'id': 'arteon', 'name': 'Arteon', 'symbol': 'arteon'},
#  {'id': 'artery', 'name': 'Artery', 'symbol': 'artr'},
#  {'id': 'artex', 'name': 'Artex', 'symbol': 'artex'},
#  {'id': 'artfinity-token', 'name': 'Artfinity Token', 'symbol': 'at'},
#  {'id': 'arth', 'name': 'ARTH', 'symbol': 'arth'},
#  {'id': 'arthx', 'name': 'ARTHX', 'symbol': 'arthx'},
#  {'id': 'articuno-inu', 'name': 'Articuno Inu', 'symbol': 'articuno'},
#  {'id': 'artificial-intelligence',
#   'name': 'Artificial Intelligence',
#   'symbol': 'ai'},
#  {'id': 'artii-token', 'name': 'ARTII Token', 'symbol': 'artii'},
#  {'id': 'arti-project', 'name': 'Arti Project', 'symbol': 'arti'},
#  {'id': 'artm', 'name': 'ARTM', 'symbol': 'artm'},
#  {'id': 'art-nano', 'name': 'ART-NANO', 'symbol': 'ARNO'},
#  {'id': 'art-of-war', 'name': 'Art of War', 'symbol': '$AOW'},
#  {'id': 'artonline', 'name': 'ArtOnline', 'symbol': 'art'},
#  {'id': 'artube', 'name': 'Artube', 'symbol': 'att'},
#  {'id': 'artverse-token', 'name': 'Artverse Token', 'symbol': 'avt'},
#  {'id': 'artwork-nft', 'name': 'Artwork NFT', 'symbol': 'anft'},
#  {'id': 'artx', 'name': 'ARTX', 'symbol': 'artx'},
#  {'id': 'arweave', 'name': 'Arweave', 'symbol': 'ar'},
#  {'id': 'aryacoin', 'name': 'Aryacoin', 'symbol': 'aya'},
#  {'id': 'ascend', 'name': 'Ascend', 'symbol': 'ACE'},
#  {'id': 'ascension', 'name': 'Ascension', 'symbol': 'asn'},
#  {'id': 'ascensionarcade', 'name': 'AscensionArcade', 'symbol': 'aat'},
#  {'id': 'ascension-protocol',
#   'name': 'Ascension Protocol',
#   'symbol': 'ascend'},
#  {'id': 'ascentpad', 'name': 'AscentPad', 'symbol': 'asp'},
#  {'id': 'asch', 'name': 'Asch', 'symbol': 'xas'},
#  {'id': 'asd', 'name': 'AscendEx Token', 'symbol': 'asd'},
#  {'id': 'asec-frontier', 'name': 'ASEC Frontier', 'symbol': 'asec'},
#  {'id': 'asgard-dao', 'name': 'Asgard Dao', 'symbol': 'asgard'},
#  {'id': 'asgardian-aereus', 'name': 'Asgardian Aereus', 'symbol': 'volt'},
#  {'id': 'ash', 'name': 'ASH', 'symbol': 'ash'},
#  {'id': 'ashera', 'name': 'Ashera', 'symbol': 'ash'},
#  {'id': 'asia-coin', 'name': 'Asia Coin', 'symbol': 'ASIA'},
#  {'id': 'asia-pacific-electronic-coin',
#   'name': 'Asia Pacific Electronic Coin',
#   'symbol': 'apecoin'},
#  {'id': 'asimi', 'name': 'ASIMI', 'symbol': 'asimi'},
#  {'id': 'ask-me-anything', 'name': 'Ask Me Anything', 'symbol': 'ama'},
#  {'id': 'askobar-network', 'name': 'Asko', 'symbol': 'asko'},
#  {'id': 'aspire', 'name': 'Aspire', 'symbol': 'asp'},
#  {'id': 'aspo-world', 'name': 'ASPO World', 'symbol': 'aspo'},
#  {'id': 'as-roma-fan-token', 'name': 'AS Roma Fan Token', 'symbol': 'asr'},
#  {'id': 'assemble-protocol', 'name': 'Assemble Protocol', 'symbol': 'asm'},
#  {'id': 'asset-backed-protocol',
#   'name': 'Asset Backed Protocol',
#   'symbol': 'abp'},
#  {'id': 'assgard', 'name': 'Assgard', 'symbol': 'assg'},
#  {'id': 'assy-index', 'name': 'ASSY Index', 'symbol': 'assy'},
#  {'id': 'asta', 'name': 'ASTA', 'symbol': 'asta'},
#  {'id': 'astar', 'name': 'Astar', 'symbol': 'astr'},
#  {'id': 'aster', 'name': 'Aster', 'symbol': 'atc'},
#  {'id': 'ast-finance', 'name': 'AST.finance', 'symbol': 'ast'},
#  {'id': 'aston', 'name': 'Aston', 'symbol': 'atx'},
#  {'id': 'aston-martin-cognizant-fan-token',
#   'name': 'Aston Martin Cognizant Fan Token',
#   'symbol': 'am'},
#  {'id': 'aston-villa-fan-token',
#   'name': 'Aston Villa Fan Token',
#   'symbol': 'avl'},
#  {'id': 'astra-guild-ventures',
#   'name': 'Astra Guild Ventures',
#   'symbol': 'agv'},
#  {'id': 'astrapad', 'name': 'AstraPad', 'symbol': 'astra'},
#  {'id': 'astra-protocol', 'name': 'Astra Coin', 'symbol': 'astra'},
#  {'id': 'astro', 'name': 'Astro', 'symbol': 'astro'},
#  {'id': 'astrobirdz', 'name': 'AstroBirdz', 'symbol': 'abz'},
#  {'id': 'astrodonkey', 'name': 'AstroDonkey', 'symbol': 'dnky'},
#  {'id': 'astro-dragon', 'name': 'Astro Dragon', 'symbol': 'dragn'},
#  {'id': 'astroelon', 'name': 'AstroElon', 'symbol': 'elonone'},
#  {'id': 'astrofarms', 'name': 'AstroFarms', 'symbol': 'leo'},
#  {'id': 'astro-gold', 'name': 'Astro Gold', 'symbol': 'astrogold'},
#  {'id': 'astrokitty', 'name': 'Astrokitties', 'symbol': 'ak'},
#  {'id': 'astrolion', 'name': 'AstroLion', 'symbol': 'astrolion'},
#  {'id': 'astronaut', 'name': 'Astronaut', 'symbol': 'naut'},
#  {'id': 'astronodes', 'name': 'AstroNodes', 'symbol': 'astro'},
#  {'id': 'astronos', 'name': 'Astronos', 'symbol': 'astro'},
#  {'id': 'astroport', 'name': 'Astroport', 'symbol': 'astro'},
#  {'id': 'astrosanta', 'name': 'AstroSanta', 'symbol': 'asa'},
#  {'id': 'astrospaces-io', 'name': 'AstroSpaces.io', 'symbol': 'spaces'},
#  {'id': 'astroswap', 'name': 'AstroSwap', 'symbol': 'astro'},
#  {'id': 'astrotools', 'name': 'AstroTools', 'symbol': 'astro'},
#  {'id': 'astro-verse', 'name': 'Astro Verse', 'symbol': 'asv'},
#  {'id': 'asuka-inu', 'name': 'Asuka Inu', 'symbol': 'asuka'},
#  {'id': 'asuna-inu', 'name': 'Asuna Inu', 'symbol': 'asunainu'},
#  {'id': 'asva', 'name': 'Asva Labs', 'symbol': 'asva'},
#  {'id': 'asyagro', 'name': 'ASYAGRO', 'symbol': 'asy'},
#  {'id': 'atari', 'name': 'Atari', 'symbol': 'atri'},
#  {'id': 'ata-token', 'name': 'ATA Token', 'symbol': 'ata'},
#  {'id': 'atauro', 'name': 'Atauro', 'symbol': 'ATR'},
#  {'id': 'atbcoin', 'name': 'ATBCoin', 'symbol': 'atb'},
#  {'id': 'atd', 'name': 'A2DAO', 'symbol': 'atd'},
#  {'id': 'at-finance', 'name': 'AT Finance', 'symbol': 'at'},
#  {'id': 'atheios', 'name': 'Atheios', 'symbol': 'ath'},
#  {'id': 'athena-money', 'name': 'Athena Money', 'symbol': 'ath'},
#  {'id': 'atheneum', 'name': 'Atheneum', 'symbol': 'aem'},
#  {'id': 'ath-games', 'name': 'ATH Games', 'symbol': 'ATHD'},
#  {'id': 'athletex', 'name': 'AthleteX', 'symbol': 'AX'},
#  {'id': 'atlant', 'name': 'Atlant', 'symbol': 'atl'},
#  {'id': 'atlantic-finance', 'name': 'Atlantic Finance', 'symbol': 'atfi'},
#  {'id': 'atlantis', 'name': 'Atlantis', 'symbol': 'atlas'},
#  {'id': 'atlantis-loans', 'name': 'Atlantis Loans', 'symbol': 'atl'},
#  {'id': 'atlantis-loans-polygon',
#   'name': 'Atlantis Loans Polygon',
#   'symbol': 'atlx'},
#  {'id': 'atlantis-metaverse', 'name': 'Atlantis Metaverse', 'symbol': 'tau'},
#  {'id': 'atlantis-token', 'name': 'Atlantis Token', 'symbol': 'atis'},
#  {'id': 'atlas-cloud', 'name': 'Atlas Cloud', 'symbol': 'atlas'},
#  {'id': 'atlas-protocol', 'name': 'Atlas Protocol', 'symbol': 'ATP'},
#  {'id': 'atlas-usv', 'name': 'Atlas USV', 'symbol': 'usv'},
#  {'id': 'atletico-madrid',
#   'name': 'Atletico Madrid Fan Token',
#   'symbol': 'atm'},
#  {'id': 'atmos', 'name': 'Atmos', 'symbol': 'atmos'},
#  {'id': 'atn', 'name': 'ATN', 'symbol': 'atn'},
#  {'id': 'atomic-token', 'name': 'Atomic Token', 'symbol': 'atmc'},
#  {'id': 'atomic-wallet-coin', 'name': 'Atomic Wallet Coin', 'symbol': 'awc'},
#  {'id': 'atompad', 'name': 'AtomPad', 'symbol': 'atpad'},
#  {'id': 'atrollcity', 'name': 'Atrollcity', 'symbol': 'pine'},
#  {'id': 'atromg8', 'name': 'ATROMG8', 'symbol': 'ag8'},
#  {'id': 'attack-wagon', 'name': 'Attack Wagon', 'symbol': 'atk'},
#  {'id': 'attila', 'name': 'Attila', 'symbol': 'att'},
#  {'id': 'attlas-token', 'name': 'Attlas Token', 'symbol': 'ats'},
#  {'id': 'attn', 'name': 'ATTN', 'symbol': 'attn'},
#  {'id': 'attrace', 'name': 'Attrace', 'symbol': 'attr'},
#  {'id': 'auction', 'name': 'Bounce', 'symbol': 'auction'},
#  {'id': 'auctus', 'name': 'Auctus', 'symbol': 'auc'},
#  ...]

# %%
cg.get_coin_by_id()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-2487b62a78ba> in <module>()
# ----> 1 cg.get_coin_by_id()
#
# /usr/local/lib/python3.7/dist-packages/pycoingecko/utils.py in input_args(*args, **kwargs)
#      10         args = [arg_preprocessing(v) for v in args]
#      11
# ---> 12         return func(*args, **kwargs)
#      13
#      14     return input_args
#
# TypeError: get_coin_by_id() missing 1 required positional argument: 'id'

# %%
cg.get_derivatives()
# Out:
# [{'basis': 0.013683086529197305,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41573.73779225,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 3180812756.98,
#   'price': '41682.96',
#   'price_percentage_change_24h': -2.0983542001352364,
#   'spread': 0.01,
#   'symbol': 'BTCUSDT',
#   'volume_24h': 11486428606.029348},
#  {'basis': 0.023107669248063952,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.441413,
#   'index_id': 'USDT',
#   'last_traded_at': 1642517985,
#   'market': 'Bitget Futures',
#   'open_interest': 2063314587.01,
#   'price': '1.44',
#   'price_percentage_change_24h': -4.8628807584139855,
#   'spread': 0.01,
#   'symbol': 'ADAUSDT_UMCBL',
#   'volume_24h': 132783666.1304666},
#  {'basis': -0.023898515355302578,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0336,
#   'index': 41715.028344468,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518722,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 2038745495.01,
#   'price': '41725.0',
#   'price_percentage_change_24h': -1.9411999717985475,
#   'spread': 0.01,
#   'symbol': 'BTC-PERP',
#   'volume_24h': 3303505739.6182},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': None,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518003,
#   'market': 'Prime XBT',
#   'open_interest': 1483713800.0,
#   'price': '41370.6',
#   'price_percentage_change_24h': -2.5953019454758213,
#   'spread': 0.02,
#   'symbol': 'BTC/USD',
#   'volume_24h': 203202689.93136},
#  {'basis': 0.027596815109712063,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3133.15441228,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 1479604635.58,
#   'price': '3140.95',
#   'price_percentage_change_24h': -2.935826441030917,
#   'spread': 0.01,
#   'symbol': 'ETHUSDT',
#   'volume_24h': 5180169748.862042},
#  {'basis': -0.00912648878866384,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41414.12,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 1454932148.83,
#   'price': '41490.74',
#   'price_percentage_change_24h': -2.785608160601999,
#   'spread': 0.01,
#   'symbol': 'BTC_USDT',
#   'volume_24h': 1214599888.4346538},
#  {'basis': -0.01905761532832782,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0744,
#   'index': 3142.600981035,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518710,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 1348645159.62,
#   'price': '3143.2',
#   'price_percentage_change_24h': -2.7866266662542913,
#   'spread': 0.01,
#   'symbol': 'ETH-PERP',
#   'volume_24h': 1669586756.7141},
#  {'basis': 0.02443022919412389,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3111.66,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517969,
#   'market': 'Bitfinex (Futures)',
#   'open_interest': 1053855444.21,
#   'price': '3110.9',
#   'price_percentage_change_24h': -3.59179372753192,
#   'spread': 0.05,
#   'symbol': 'ETHF0:USTF0',
#   'volume_24h': 87346668.20810093},
#  {'basis': 0.031843401619532516,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41593.14045455,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 1046797700.0,
#   'price': '41579.9',
#   'price_percentage_change_24h': -2.0960628771771197,
#   'spread': 0.01,
#   'symbol': 'BTCUSD_PERP',
#   'volume_24h': 4139319657.902461},
#  {'basis': 0.03649864551083591,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41359.09,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517769,
#   'market': 'C-Trade',
#   'open_interest': 947020067.0,
#   'price': '41344.0',
#   'price_percentage_change_24h': -2.6031237484981977,
#   'spread': 0.01,
#   'symbol': 'BTCUSD',
#   'volume_24h': 29232065.18571008},
#  {'basis': -0.02503382949932341,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0031,
#   'index': 41373.64,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517805,
#   'market': 'Bybit',
#   'open_interest': 907638837.0,
#   'price': '41384.0',
#   'price_percentage_change_24h': -2.6258823529411766,
#   'spread': 0.01,
#   'symbol': 'BTCUSD',
#   'volume_24h': 1399174831.04},
#  {'basis': -0.026388922452333197,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41370.08,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517805,
#   'market': 'Bybit',
#   'open_interest': 832114717.67,
#   'price': '41506.73',
#   'price_percentage_change_24h': -2.6260677224274653,
#   'spread': 0.01,
#   'symbol': 'BTCUSDT',
#   'volume_24h': 2331053127.66002},
#  {'basis': -0.040556982560511,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.7394,
#   'index_id': 'XRP',
#   'last_traded_at': 1642517769,
#   'market': 'C-Trade',
#   'open_interest': 707699392.61,
#   'price': '0.74',
#   'price_percentage_change_24h': -2.6069783,
#   'spread': 0.01,
#   'symbol': 'XRPUSDT',
#   'volume_24h': 2113376.2359309797},
#  {'basis': -0.003285024154589372,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 6e-06,
#   'index': 41398.64,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517969,
#   'market': 'Crypto.com Exchange (Futures)',
#   'open_interest': 706684710.6,
#   'price': '41400.0',
#   'price_percentage_change_24h': -2.589381301396454,
#   'spread': 0.04,
#   'symbol': 'BTCUSD-PERP',
#   'volume_24h': 706684710.6},
#  {'basis': 0.017082225564345674,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 41404.571614328,
#   'index_id': 'BTCPFC',
#   'last_traded_at': 1642517676,
#   'market': 'BTSE (Futures)',
#   'open_interest': 604008524.01,
#   'price': '41397.5',
#   'price_percentage_change_24h': -2.606721483102187,
#   'spread': 0.02,
#   'symbol': 'BTCPFC',
#   'volume_24h': 967581125.7870001},
#  {'basis': -0.03151047329129521,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 41377.9575,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517970,
#   'market': 'Bitfinex (Futures)',
#   'open_interest': 565750728.97,
#   'price': '41391.0',
#   'price_percentage_change_24h': -2.549795168809154,
#   'spread': 0.01,
#   'symbol': 'BTCF0:USTF0',
#   'volume_24h': 234381791.57792678},
#  {'basis': -0.00021736242769680356,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -9.3e-05,
#   'index': 41405.41,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517980,
#   'market': 'Deribit',
#   'open_interest': 516859570.0,
#   'price': '41405.5',
#   'price_percentage_change_24h': -2.5993578057185873,
#   'spread': 0.01,
#   'symbol': 'BTC-PERPETUAL',
#   'volume_24h': 393551921.0585168},
#  {'basis': 0.005465271415023067,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3110.72,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517806,
#   'market': 'Bybit',
#   'open_interest': 509584986.0,
#   'price': '3110.55',
#   'price_percentage_change_24h': -3.73688608300065,
#   'spread': 0.01,
#   'symbol': 'ETHUSD',
#   'volume_24h': 445485754.524},
#  {'basis': 0.043371257527091145,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3133.37839646,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 461974010.0,
#   'price': '3132.02',
#   'price_percentage_change_24h': -2.9760632448289854,
#   'spread': 0.01,
#   'symbol': 'ETHUSD_PERP',
#   'volume_24h': 3041546115.0992117},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': None,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518003,
#   'market': 'Prime XBT',
#   'open_interest': 426983400.0,
#   'price': '3113.38',
#   'price_percentage_change_24h': -3.6376748346441095,
#   'spread': 0.03,
#   'symbol': 'ETH/USD',
#   'volume_24h': 42952950.14472},
#  {'basis': 0.07471423915798621,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41455.45,
#   'index_id': 'BXBT',
#   'last_traded_at': 1642518002,
#   'market': 'BitMEX',
#   'open_interest': 424728200.0,
#   'price': '41424.5',
#   'price_percentage_change_24h': -2.499617525566945,
#   'spread': 0.01,
#   'symbol': 'XBTUSD',
#   'volume_24h': 659483735.3782831},
#  {'basis': 0.03448826441002714,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3132.58,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518446,
#   'market': 'Hopex',
#   'open_interest': 419355131.89,
#   'price': '3140.16',
#   'price_percentage_change_24h': -2.911266819619272,
#   'spread': None,
#   'symbol': 'ETHUSDT',
#   'volume_24h': 850412356.7428943},
#  {'basis': -0.0005741035082420581,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0096,
#   'index': 137.40421115307447,
#   'index_id': 'SOL',
#   'last_traded_at': 1642518711,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 402475008.1,
#   'price': '137.41',
#   'price_percentage_change_24h': -3.7493651822145946,
#   'spread': 0.01,
#   'symbol': 'SOL-PERP',
#   'volume_24h': 304274879.9777},
#  {'basis': -0.07959194051375487,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01514,
#   'index': 3114.958769009648,
#   'index_id': 'OkexSwap-ETH',
#   'last_traded_at': 1642518014,
#   'market': 'OKEx (Futures)',
#   'open_interest': 372653465.09,
#   'price': '3122.92',
#   'price_percentage_change_24h': -3.3651580905145693,
#   'spread': 0.01,
#   'symbol': 'ETH-USDT-SWAP',
#   'volume_24h': 5411432774.742733},
#  {'basis': 0.01345416268405706,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41331.06,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517769,
#   'market': 'C-Trade',
#   'open_interest': 345271820.79,
#   'price': '41179.35',
#   'price_percentage_change_24h': -2.8800733237761746,
#   'spread': 0.03,
#   'symbol': 'BTCUSDT',
#   'volume_24h': 5750778.917175341},
#  {'basis': -0.09770255164011156,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.002377,
#   'index': 41407.903855586,
#   'index_id': 'OkexSwap-BTC',
#   'last_traded_at': 1642518012,
#   'market': 'OKEx (Futures)',
#   'open_interest': 336147137.83,
#   'price': '41521.29',
#   'price_percentage_change_24h': -2.355111300623585,
#   'spread': 0.01,
#   'symbol': 'BTC-USDT-SWAP',
#   'volume_24h': 2707201970.790777},
#  {'basis': 0.007386473119660865,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0068,
#   'index': 3114.03,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517981,
#   'market': 'Deribit',
#   'open_interest': 319453091.0,
#   'price': '3113.8',
#   'price_percentage_change_24h': -3.697403621630816,
#   'spread': 0.01,
#   'symbol': 'ETH-PERPETUAL',
#   'volume_24h': 235840739.77865258},
#  {'basis': 0.06169424668077737,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41601.65,
#   'index_id': 'KXBTUSDT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 319038829.22,
#   'price': '41690.94',
#   'price_percentage_change_24h': -2.3900079823449314,
#   'spread': 0.01,
#   'symbol': 'XBTUSDTM',
#   'volume_24h': 1029779594.4051098},
#  {'basis': 0.02023894808870442,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -6e-06,
#   'index': 3113.44,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517967,
#   'market': 'Crypto.com Exchange (Futures)',
#   'open_interest': 284995399.22,
#   'price': '3112.81',
#   'price_percentage_change_24h': -3.6472649382165763,
#   'spread': 0.06,
#   'symbol': 'ETHUSD-PERP',
#   'volume_24h': 284995399.218361},
#  {'basis': 0.05107655172413793,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.45074061,
#   'index_id': 'ADA',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 252895514.88,
#   'price': '1.45',
#   'price_percentage_change_24h': -4.220886452209525,
#   'spread': 0.02,
#   'symbol': 'ADAUSDT',
#   'volume_24h': 3145399833.680035},
#  {'basis': 0.046549155908639527,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 16.1195,
#   'index_id': 'UNI',
#   'last_traded_at': 1642517928,
#   'market': 'Phemex (Futures)',
#   'open_interest': 242421264.78,
#   'price': '16.11',
#   'price_percentage_change_24h': -2.2270768857333576,
#   'spread': 0.11,
#   'symbol': 'UNIUSD',
#   'volume_24h': 2800551.0},
#  {'basis': 0.017274641178982253,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.000377,
#   'index': 41648.193333333336,
#   'index_id': 'OkexSwap-BTC',
#   'last_traded_at': 1642518008,
#   'market': 'OKEx (Futures)',
#   'open_interest': 240957300.0,
#   'price': '41450.4',
#   'price_percentage_change_24h': -2.393628920406246,
#   'spread': 0.01,
#   'symbol': 'BTC-USD-SWAP',
#   'volume_24h': 575947397.17296},
#  {'basis': 0.022833252934555393,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3110.21,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517805,
#   'market': 'Bybit',
#   'open_interest': 239786207.03,
#   'price': '3118.95',
#   'price_percentage_change_24h': -3.7261792343297677,
#   'spread': 0.01,
#   'symbol': 'ETHUSDT',
#   'volume_24h': 429805077.64470077},
#  {'basis': 0.05584432132963989,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.044857,
#   'index': 462.33804544,
#   'index_id': 'BNB',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 217784089.71,
#   'price': '463.36',
#   'price_percentage_change_24h': -1.9895643320748313,
#   'spread': 0.01,
#   'symbol': 'BNBUSDT',
#   'volume_24h': 605550499.422591},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0014,
#   'index': 378.6,
#   'index_id': 'BCH',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 216287569.64,
#   'price': '378.6',
#   'price_percentage_change_24h': 0.15873015873015872,
#   'spread': 0.03,
#   'symbol': 'BCH-USD-SWAP-LIN',
#   'volume_24h': 4378827368.526},
#  {'basis': -0.14663368880894256,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0020393,
#   'index': 3108.635,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517788,
#   'market': 'dYdX Perpetual',
#   'open_interest': 212889516.64,
#   'price': '3113.2',
#   'price_percentage_change_24h': -3.8809472351724352,
#   'spread': 0.02,
#   'symbol': 'ETH-USD',
#   'volume_24h': 1407022296.1984},
#  {'basis': 0.0302539168017153,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.740624,
#   'index_id': 'USDT',
#   'last_traded_at': 1642517986,
#   'market': 'Bitget Futures',
#   'open_interest': 204770173.05,
#   'price': '0.74',
#   'price_percentage_change_24h': -2.8218926,
#   'spread': 0.03,
#   'symbol': 'XRPUSDT_UMCBL',
#   'volume_24h': 27049418.706209447},
#  {'basis': 0.05993762426900585,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 136.88199467,
#   'index_id': 'SOL',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 198945073.31,
#   'price': '137.18',
#   'price_percentage_change_24h': -3.898840885142255,
#   'spread': 0.02,
#   'symbol': 'SOLUSDT',
#   'volume_24h': 593694962.8372878},
#  {'basis': -0.1429502813126313,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.00254328,
#   'index': 41353.8,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517788,
#   'market': 'dYdX Perpetual',
#   'open_interest': 195792033.53,
#   'price': '41413.0',
#   'price_percentage_change_24h': -2.72701648893691,
#   'spread': 0.01,
#   'symbol': 'BTC-USD',
#   'volume_24h': 2694926396.3845},
#  {'basis': 0.011940513735160916,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.013591,
#   'index': 3160.107287994644,
#   'index_id': 'OkexSwap-ETH',
#   'last_traded_at': 1642518008,
#   'market': 'OKEx (Futures)',
#   'open_interest': 193769660.0,
#   'price': '3117.43',
#   'price_percentage_change_24h': -3.397209844254523,
#   'spread': 0.01,
#   'symbol': 'ETH-USD-SWAP',
#   'volume_24h': 367226830.223742},
#  {'basis': 0.0531619415109667,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.003624,
#   'index': 24.63308847,
#   'index_id': 'DOT',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 182014395.29,
#   'price': '24.69',
#   'price_percentage_change_24h': -5.764372655592131,
#   'spread': 0.01,
#   'symbol': 'DOTUSDT',
#   'volume_24h': 521750136.4994114},
#  {'basis': -0.016419568261940406,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3105.54,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517769,
#   'market': 'C-Trade',
#   'open_interest': 174108860.18,
#   'price': '3095.07',
#   'price_percentage_change_24h': -3.7003162398462206,
#   'spread': 0.01,
#   'symbol': 'ETHUSDT',
#   'volume_24h': 27961842.68512659},
#  {'basis': 0.044061302681992334,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3133.38,
#   'index_id': 'KETHUSDT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 163041516.27,
#   'price': '3140.66',
#   'price_percentage_change_24h': -3.4525277435265105,
#   'spread': 0.01,
#   'symbol': 'ETHUSDTM',
#   'volume_24h': 576324945.2093042},
#  {'basis': -0.0035938903863432167,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 27.824,
#   'index_id': 'FIL',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 160856138.96,
#   'price': '27.87',
#   'price_percentage_change_24h': -5.089197394003479,
#   'spread': 0.36,
#   'symbol': 'FIL_USDT',
#   'volume_24h': 6936316.961268797},
#  {'basis': 0.005015302607387919,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.048,
#   'index': 1.4596182005984415,
#   'index_id': 'ADA',
#   'last_traded_at': 1642518719,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 153548223.65,
#   'price': '1.46',
#   'price_percentage_change_24h': -3.622544827836675,
#   'spread': 0.02,
#   'symbol': 'ADA-PERP',
#   'volume_24h': 587686061.952995},
#  {'basis': -0.13518268484711682,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0369252742371,
#   'index': 3119.07783920417,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518005,
#   'market': 'MCS',
#   'open_interest': 152527770.53,
#   'price': '3128.79',
#   'price_percentage_change_24h': -3.4065781131608652,
#   'spread': 0.08,
#   'symbol': 'ETHUSDT_QUANTO_PERP',
#   'volume_24h': 1927507.844907629},
#  {'basis': -0.0034076,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.74507461,
#   'index_id': 'XRP',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 149413469.38,
#   'price': '0.75',
#   'price_percentage_change_24h': -1.8442893,
#   'spread': 0.01,
#   'symbol': 'XRPUSDT',
#   'volume_24h': 307713385.83666605},
#  {'basis': 0.03174766548441926,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0432,
#   'index': 24.7178448481412,
#   'index_id': 'DOT',
#   'last_traded_at': 1642518707,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 147942545.69,
#   'price': '24.71',
#   'price_percentage_change_24h': -5.578907145586549,
#   'spread': 0.03,
#   'symbol': 'DOT-PERP',
#   'volume_24h': 178273067.8531},
#  {'basis': 0.055819145967066705,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.434,
#   'index_id': 'ADA',
#   'last_traded_at': 1642517928,
#   'market': 'Phemex (Futures)',
#   'open_interest': 143062941.25,
#   'price': '1.43',
#   'price_percentage_change_24h': -5.224176696204206,
#   'spread': 0.12,
#   'symbol': 'ADAUSD',
#   'volume_24h': 14111814.0},
#  {'basis': 0.025516468952270756,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41408.66333333333,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518002,
#   'market': 'Huobi Futures',
#   'open_interest': 143031502.51,
#   'price': '41470.9',
#   'price_percentage_change_24h': -2.4602813702367685,
#   'spread': 0.01,
#   'symbol': 'BTC-USDT',
#   'volume_24h': 532242392.6448049},
#  {'basis': 0.09549352877989992,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 76.41089785,
#   'index_id': 'LUNA',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 135617921.55,
#   'price': '76.55',
#   'price_percentage_change_24h': -5.8880094681559285,
#   'spread': 0.01,
#   'symbol': 'LUNAUSDT',
#   'volume_24h': 1040088280.0401102},
#  {'basis': 0.10822410996563574,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.044224,
#   'index': 72.82873304,
#   'index_id': 'AXS',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 132621503.01,
#   'price': '72.95',
#   'price_percentage_change_24h': -7.899734143562476,
#   'spread': 0.03,
#   'symbol': 'AXSUSDT',
#   'volume_24h': 243118349.95041156},
#  {'basis': 0.0371993,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.16302062,
#   'index_id': 'DOGE',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 131499735.37,
#   'price': '0.16',
#   'price_percentage_change_24h': -3.0,
#   'spread': 0.02,
#   'symbol': 'DOGEUSDT',
#   'volume_24h': 825514134.8158046},
#  {'basis': 0.038948488255418946,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.006859,
#   'index': 41375.6089,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517928,
#   'market': 'Phemex (Futures)',
#   'open_interest': 129907518.0,
#   'price': '41359.5',
#   'price_percentage_change_24h': -2.5757896968412126,
#   'spread': 0.01,
#   'symbol': 'BTCUSD',
#   'volume_24h': 1152544810.0},
#  {'basis': -0.0020933742869679683,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 17.09214219,
#   'index_id': 'NEAR',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 126614420.18,
#   'price': '17.14',
#   'price_percentage_change_24h': -9.090667333273055,
#   'spread': 0.01,
#   'symbol': 'NEARUSDT',
#   'volume_24h': 1114724822.0876372},
#  {'basis': -0.0306469966081914,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 2.74105969,
#   'index_id': 'FTM',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 123585308.15,
#   'price': '2.75',
#   'price_percentage_change_24h': -12.516750685980474,
#   'spread': 0.02,
#   'symbol': 'FTMUSDT',
#   'volume_24h': 1671389766.7576926},
#  {'basis': 0.02900703757801089,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 22.59955356,
#   'index_id': 'LINK',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 123280850.54,
#   'price': '22.66',
#   'price_percentage_change_24h': -6.959601367211629,
#   'spread': 0.01,
#   'symbol': 'LINKUSDT',
#   'volume_24h': 482045944.75369054},
#  {'basis': 0.05819459073859078,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0576,
#   'index': 84.56418315836272,
#   'index_id': 'AVAX',
#   'last_traded_at': 1642518711,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 121861882.7,
#   'price': '84.52',
#   'price_percentage_change_24h': -4.527636885329237,
#   'spread': 0.03,
#   'symbol': 'AVAX-PERP',
#   'volume_24h': 106319932.4776},
#  {'basis': 0.025949509567454575,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.008653,
#   'index': 3110.3069,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517928,
#   'market': 'Phemex (Futures)',
#   'open_interest': 121664689.46,
#   'price': '3109.5',
#   'price_percentage_change_24h': -3.61128332300062,
#   'spread': 0.01,
#   'symbol': 'ETHUSD',
#   'volume_24h': 49850610.0},
#  {'basis': 0.01595143931706144,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41591.63340604,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 120320160.3,
#   'price': '41410.75',
#   'price_percentage_change_24h': -2.1119433550993123,
#   'spread': 0.01,
#   'symbol': 'BTCBUSD',
#   'volume_24h': 706050290.8623914},
#  {'basis': 0.044800109788493886,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0864,
#   'index': 43.4224445916515,
#   'index_id': 'FTT',
#   'last_traded_at': 1642518703,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 110244826.6,
#   'price': '43.4',
#   'price_percentage_change_24h': -4.0266230320183976,
#   'spread': 0.06,
#   'symbol': 'FTT-PERP',
#   'volume_24h': 128259201.28605},
#  {'basis': 0.0146951,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.01,
#   'index': 0.06806,
#   'index_id': 'USDT',
#   'last_traded_at': 1642517985,
#   'market': 'Bitget Futures',
#   'open_interest': 109430505.09,
#   'price': '0.07',
#   'price_percentage_change_24h': -3.9384529,
#   'spread': 0.04,
#   'symbol': 'TRXUSDT_UMCBL',
#   'volume_24h': 3719316.436289191},
#  {'basis': -0.04521327928971241,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.004,
#   'index': 41429.26,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518004,
#   'market': 'Bitforex (Futures)',
#   'open_interest': 104583566.0,
#   'price': '41448.0',
#   'price_percentage_change_24h': -2.4615239798559796,
#   'spread': 0.1,
#   'symbol': 'SWAP-USD-BTC',
#   'volume_24h': 875929877.0},
#  {'basis': 0.052588542752240626,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0319,
#   'index': 3120.19,
#   'index_id': 'BETH',
#   'last_traded_at': 1642518002,
#   'market': 'BitMEX',
#   'open_interest': 104405033.28,
#   'price': '3118.55',
#   'price_percentage_change_24h': -3.8701026478838507,
#   'spread': 0.01,
#   'symbol': 'ETHUSD',
#   'volume_24h': 162250207.62595847},
#  {'basis': -0.0809935,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.7402,
#   'index_id': 'XRP',
#   'last_traded_at': 1642517805,
#   'market': 'Bybit',
#   'open_interest': 104308827.0,
#   'price': '0.74',
#   'price_percentage_change_24h': -2.5775907,
#   'spread': 0.01,
#   'symbol': 'XRPUSD',
#   'volume_24h': 134833763.8342397},
#  {'basis': 0.02638754826254826,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0017005590477804,
#   'index': 41450.935,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518001,
#   'market': 'Huobi Futures',
#   'open_interest': 103818600.0,
#   'price': '41440.0',
#   'price_percentage_change_24h': -2.413063085339117,
#   'spread': 0.01,
#   'symbol': 'BTC-USD',
#   'volume_24h': 345703166.98279697},
#  {'basis': -0.013757980231954719,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.000194124135,
#   'index': 41424.8,
#   'index_id': 'KrakenFutures-rr_xbtusd',
#   'last_traded_at': 1642518005,
#   'market': 'Kraken (Futures)',
#   'open_interest': 99006091.0,
#   'price': '41430.5',
#   'price_percentage_change_24h': -2.6584746957379823,
#   'spread': 0.04,
#   'symbol': 'PI_XBTUSD',
#   'volume_24h': 127920043.0},
#  {'basis': 0.0631236174896057,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 36.82222886,
#   'index_id': 'ATOM',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 97135329.66,
#   'price': '36.9',
#   'price_percentage_change_24h': -10.338190146679011,
#   'spread': 0.02,
#   'symbol': 'ATOMUSDT',
#   'volume_24h': 733765905.60451},
#  {'basis': -0.11348897535667964,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 24.644,
#   'index_id': 'KDOTUSD',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 90792145.82,
#   'price': '24.67',
#   'price_percentage_change_24h': -5.821277245486124,
#   'spread': 0.04,
#   'symbol': 'DOTUSDM',
#   'volume_24h': 1433349.0},
#  {'basis': 0.0207893826105533,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.007024,
#   'index': 140.45919453,
#   'index_id': 'LTC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 89275430.02,
#   'price': '140.82',
#   'price_percentage_change_24h': -7.264082414316846,
#   'spread': 0.02,
#   'symbol': 'LTCUSDT',
#   'volume_24h': 643809275.2681893},
#  {'basis': 0.009682096578964133,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0006161187310179,
#   'index': 3139.70395974,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518722,
#   'market': 'ZBG Futures',
#   'open_interest': 87201033.28,
#   'price': '3155.05',
#   'price_percentage_change_24h': -3.10344295436658,
#   'spread': 0.02,
#   'symbol': 'ETH_USDT',
#   'volume_24h': 506986.64924338466},
#  {'basis': 0.04184526075371146,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 2.10247942,
#   'index_id': 'MATIC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 86879041.76,
#   'price': '2.11',
#   'price_percentage_change_24h': -8.570434177325328,
#   'spread': 0.02,
#   'symbol': 'MATICUSDT',
#   'volume_24h': 725915802.2334526},
#  {'basis': -0.011679945529195117,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0528,
#   'index': 37.19365529386205,
#   'index_id': 'ATOM',
#   'last_traded_at': 1642518711,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 83810831.84,
#   'price': '37.2',
#   'price_percentage_change_24h': -9.657676474516995,
#   'spread': 0.03,
#   'symbol': 'ATOM-PERP',
#   'volume_24h': 197510970.574665},
#  {'basis': -0.08855769230769231,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.005,
#   'index': 3117.237,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518004,
#   'market': 'Bitforex (Futures)',
#   'open_interest': 83808345.0,
#   'price': '3120.0',
#   'price_percentage_change_24h': -3.410058356423076,
#   'spread': 0.02,
#   'symbol': 'SWAP-USD-ETH',
#   'volume_24h': 527582195.0},
#  {'basis': 0.07317349645585713,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0080016886713418,
#   'index': 41719.00493307,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518722,
#   'market': 'ZBG Futures',
#   'open_interest': 83007297.69,
#   'price': '41896.31',
#   'price_percentage_change_24h': -2.0062526444454893,
#   'spread': 0.04,
#   'symbol': 'BTC_USDT',
#   'volume_24h': 976169.793440029},
#  {'basis': 0.08413049910102642,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 4.39759661,
#   'index_id': 'SAND',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 82400147.15,
#   'price': '4.41',
#   'price_percentage_change_24h': -5.517686270293517,
#   'spread': 0.01,
#   'symbol': 'SANDUSDT',
#   'volume_24h': 442310736.3057676},
#  {'basis': 8.331666666666666e-07,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 1.0002000083333333,
#   'index_id': 'USDT',
#   'last_traded_at': 1642518719,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 80973688.9,
#   'price': '1.0',
#   'price_percentage_change_24h': -0.009997000899730081,
#   'spread': 0.02,
#   'symbol': 'USDT-PERP',
#   'volume_24h': 9340814.7943},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': None,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518003,
#   'market': 'Prime XBT',
#   'open_interest': 80476400.0,
#   'price': '3110.27',
#   'price_percentage_change_24h': -0.9769281,
#   'spread': 0.13,
#   'symbol': 'ETH/BTC',
#   'volume_24h': 555009.465944152},
#  {'basis': 0.08492554096063264,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0072,
#   'index': 2.117381672005732,
#   'index_id': 'MATIC',
#   'last_traded_at': 1642518708,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 80142880.81,
#   'price': '2.12',
#   'price_percentage_change_24h': -7.891193632970624,
#   'spread': 0.03,
#   'symbol': 'MATIC-PERP',
#   'volume_24h': 150377633.6496175},
#  {'basis': -0.13079094100640187,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.4508,
#   'index_id': 'KADAUSDT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 79665288.98,
#   'price': '1.46',
#   'price_percentage_change_24h': -3.6524138296955106,
#   'spread': 0.05,
#   'symbol': 'ADAUSDTM',
#   'volume_24h': 310568086.9368977},
#  {'basis': -0.07288098535092194,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 2.7422,
#   'index_id': 'KFTMUSDT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 79433606.66,
#   'price': '2.75',
#   'price_percentage_change_24h': -12.47129369737178,
#   'spread': 0.01,
#   'symbol': 'FTMUSDTM',
#   'volume_24h': 192213875.20943117},
#  {'basis': -0.012534337542617518,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 84.16844872,
#   'index_id': 'AVAX',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 77846370.84,
#   'price': '84.41',
#   'price_percentage_change_24h': -4.685394657880137,
#   'spread': 0.01,
#   'symbol': 'AVAXUSDT',
#   'volume_24h': 311112110.2317538},
#  {'basis': 0.019329250007912958,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0216,
#   'index': 22.75189692114555,
#   'index_id': 'LINK',
#   'last_traded_at': 1642518717,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 77734922.56,
#   'price': '22.75',
#   'price_percentage_change_24h': -6.615624615131984,
#   'spread': 0.01,
#   'symbol': 'LINK-PERP',
#   'volume_24h': 122496102.1496},
#  {'basis': 0.0411880168613444,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3108.98,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517769,
#   'market': 'C-Trade',
#   'open_interest': 76051104.0,
#   'price': '3107.7',
#   'price_percentage_change_24h': -3.758071259348725,
#   'spread': 0.01,
#   'symbol': 'ETHUSD',
#   'volume_24h': 3680003.367399141},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0014,
#   'index': 5.5,
#   'index_id': 'FLEX',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 74451198.8,
#   'price': '5.5',
#   'price_percentage_change_24h': 3.3251925605861357,
#   'spread': 0.04,
#   'symbol': 'FLEX-USD-SWAP-LIN',
#   'volume_24h': 1706323438.6},
#  {'basis': -0.0449734,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.02813734,
#   'index_id': '1000SHIB',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 73769136.3,
#   'price': '0.03',
#   'price_percentage_change_24h': -3.011301,
#   'spread': 0.03,
#   'symbol': '1000SHIBUSDT',
#   'volume_24h': 461431463.3723382},
#  {'basis': -0.0689977936751889,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0528,
#   'index': 0.747334,
#   'index_id': 'XRP',
#   'last_traded_at': 1642518714,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 73364477.62,
#   'price': '0.75',
#   'price_percentage_change_24h': -1.7344458,
#   'spread': 0.01,
#   'symbol': 'XRP-PERP',
#   'volume_24h': 76605533.40745},
#  {'basis': 0.12815822298673915,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3119.9333333333334,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518001,
#   'market': 'Huobi Futures',
#   'open_interest': 73362334.25,
#   'price': '3121.42',
#   'price_percentage_change_24h': -3.4475706494794247,
#   'spread': 0.01,
#   'symbol': 'ETH-USDT',
#   'volume_24h': 260881274.11176214},
#  {'basis': 0.066633133134467,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0024,
#   'index': 0.16370300780782,
#   'index_id': 'DOGE',
#   'last_traded_at': 1642518710,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 71083084.65,
#   'price': '0.16',
#   'price_percentage_change_24h': -2.7303105,
#   'spread': 0.04,
#   'symbol': 'DOGE-PERP',
#   'volume_24h': 206569812.1035625},
#  {'basis': 0.022713675620478383,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.054614,
#   'index': 462.32898806,
#   'index_id': 'BNB',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 69625320.0,
#   'price': '462.22',
#   'price_percentage_change_24h': -1.820329061118026,
#   'spread': 0.01,
#   'symbol': 'BNBUSD_PERP',
#   'volume_24h': 461441131.7144094},
#  {'basis': 0.09219399123481115,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.0456,
#   'index': 463.55447572675604,
#   'index_id': 'BNB',
#   'last_traded_at': 1642518723,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 69505156.32,
#   'price': '463.13',
#   'price_percentage_change_24h': -1.961811619513331,
#   'spread': 0.02,
#   'symbol': 'BNB-PERP',
#   'volume_24h': 78218836.77875},
#  {'basis': -1.209889531825355,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.6859,
#   'index': 1.878,
#   'index_id': 'BIT',
#   'last_traded_at': 1642517806,
#   'market': 'Bybit',
#   'open_interest': 63950827.69,
#   'price': '1.91',
#   'price_percentage_change_24h': -0.10509721492380451,
#   'spread': 0.05,
#   'symbol': 'BITUSDT',
#   'volume_24h': 124568640.26305784},
#  {'basis': -0.0366542,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.29369231,
#   'index_id': 'GALA',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 63854143.73,
#   'price': '0.29',
#   'price_percentage_change_24h': -4.4273121,
#   'spread': 0.01,
#   'symbol': 'GALAUSDT',
#   'volume_24h': 329747110.74608284},
#  {'basis': -0.05876838765503317,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41579.55,
#   'index_id': 'BXBT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 61936138.0,
#   'price': '41604.0',
#   'price_percentage_change_24h': -2.3724040830693416,
#   'spread': 0.03,
#   'symbol': 'XBTUSDM',
#   'volume_24h': 46600709.0},
#  {'basis': 0.057373834779813566,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 2.80150641,
#   'index_id': 'MANA',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 61646132.64,
#   'price': '2.81',
#   'price_percentage_change_24h': -5.072046109510087,
#   'spread': 0.01,
#   'symbol': 'MANAUSDT',
#   'volume_24h': 338664074.3712336},
#  {'basis': -0.06411095119717389,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 76.381,
#   'index_id': 'KLUNAUSDT',
#   'last_traded_at': 1642518443,
#   'market': 'KuCoin Futures',
#   'open_interest': 59655175.25,
#   'price': '76.64',
#   'price_percentage_change_24h': -6.419502161056897,
#   'spread': 0.01,
#   'symbol': 'LUNAUSDTM',
#   'volume_24h': 141374669.1968527},
#  {'basis': 0.00282189263682898,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0552,
#   'index': 380.96075,
#   'index_id': 'BCH',
#   'last_traded_at': 1642518701,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 58562585.22,
#   'price': '380.95',
#   'price_percentage_change_24h': 0.7804232804232805,
#   'spread': 0.01,
#   'symbol': 'BCH-PERP',
#   'volume_24h': 42811328.71285},
#  {'basis': -0.01667201025969862,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.002509598959,
#   'index': 3118.48,
#   'index_id': 'KrakenFutures-rr_ethusd',
#   'last_traded_at': 1642518005,
#   'market': 'Kraken (Futures)',
#   'open_interest': 58323368.0,
#   'price': '3119.0',
#   'price_percentage_change_24h': -3.8547494644040627,
#   'spread': 0.12,
#   'symbol': 'PI_ETHUSD',
#   'volume_24h': 66559975.0},
#  {'basis': -0.02117437462579769,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 136.929,
#   'index_id': 'KSOLUSDT',
#   'last_traded_at': 1642518442,
#   'market': 'KuCoin Futures',
#   'open_interest': 53666741.48,
#   'price': '137.34',
#   'price_percentage_change_24h': -3.7229181604735193,
#   'spread': 0.04,
#   'symbol': 'SOLUSDTM',
#   'volume_24h': 58091055.02524158},
#  {'basis': -0.00671571847117776,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 1.103e-05,
#   'index': 135.4939,
#   'index_id': 'SOL',
#   'last_traded_at': 1642517788,
#   'market': 'dYdX Perpetual',
#   'open_interest': 53426434.5,
#   'price': '135.5',
#   'price_percentage_change_24h': -5.063406431724235,
#   'spread': 0.01,
#   'symbol': 'SOL-USD',
#   'volume_24h': 30111544.4115},
#  {'basis': -0.013052550419997566,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 24.63978346,
#   'index_id': 'DOT',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 53067100.0,
#   'price': '24.64',
#   'price_percentage_change_24h': -5.762906309751434,
#   'spread': 0.01,
#   'symbol': 'DOTUSD_PERP',
#   'volume_24h': 267353659.74923795},
#  {'basis': 0.0134935,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0014,
#   'index': 0.7412,
#   'index_id': 'XRP',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 52241320.83,
#   'price': '0.74',
#   'price_percentage_change_24h': -2.3969446,
#   'spread': 0.04,
#   'symbol': 'XRP-USD-SWAP-LIN',
#   'volume_24h': 728226040.4897801},
#  {'basis': 0.06464623655913979,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.009155,
#   'index': 2.79180363,
#   'index_id': 'EOS',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 52001886.74,
#   'price': '2.8',
#   'price_percentage_change_24h': -1.6566795911173775,
#   'spread': 0.04,
#   'symbol': 'EOSUSDT',
#   'volume_24h': 213492411.65346655},
#  {'basis': 0.0027030604999338076,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41546.623,
#   'index_id': 'BTC',
#   'last_traded_at': 1642512044,
#   'market': 'MCS',
#   'open_interest': 51165029.0,
#   'price': '41465.41',
#   'price_percentage_change_24h': -2.465049124907561,
#   'spread': 0.04,
#   'symbol': 'BTCUSDT',
#   'volume_24h': 14240510.098818354},
#  {'basis': 7.241112138276278e-05,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41430.13,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 51049264.0,
#   'price': '41430.1',
#   'price_percentage_change_24h': -2.818559897916339,
#   'spread': 0.01,
#   'symbol': 'BTC_USD',
#   'volume_24h': 10357525.0},
#  {'basis': 0.08202399895881128,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3119.18638455875,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518002,
#   'market': 'Huobi Futures',
#   'open_interest': 50662460.0,
#   'price': '3116.63',
#   'price_percentage_change_24h': -3.4202045243259995,
#   'spread': 0.01,
#   'symbol': 'ETH-USD',
#   'volume_24h': 296224643.7511306},
#  {'basis': -0.9493670886075949,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.375,
#   'index': 1.878,
#   'index_id': 'BIT',
#   'last_traded_at': 1642517806,
#   'market': 'Bybit',
#   'open_interest': 50210329.0,
#   'price': '1.9',
#   'price_percentage_change_24h': -0.47244094488188976,
#   'spread': 0.05,
#   'symbol': 'BITUSD',
#   'volume_24h': 69989276.486352},
#  {'basis': 0.0436636479282772,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.002587,
#   'index': 33.03041599,
#   'index_id': 'ETC',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 49958900.69,
#   'price': '33.11',
#   'price_percentage_change_24h': 6.647716260740358,
#   'spread': 0.03,
#   'symbol': 'ETCUSDT',
#   'volume_24h': 285799765.4129797},
#  {'basis': 0.02357768296745768,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.024,
#   'index': 1.2940050244845505,
#   'index_id': 'ALGO',
#   'last_traded_at': 1642518715,
#   'market': 'FTX (Derivatives)',
#   'open_interest': 49369755.07,
#   'price': '1.29',
#   'price_percentage_change_24h': -5.603794235680408,
#   'spread': 0.02,
#   'symbol': 'ALGO-PERP',
#   'volume_24h': 31238941.0326},
#  {'basis': 0.025676413005103187,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0014,
#   'index': 3116.5,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 49116954.14,
#   'price': '3115.7',
#   'price_percentage_change_24h': -3.4879038503236997,
#   'spread': 0.03,
#   'symbol': 'ETH-USD-SWAP-LIN',
#   'volume_24h': 515222745.38},
#  {'basis': -0.01850503122679827,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 228.92762903,
#   'index_id': 'AAVE',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 47952839.81,
#   'price': '229.6',
#   'price_percentage_change_24h': 0.7923581458819386,
#   'spread': 0.03,
#   'symbol': 'AAVEUSDT',
#   'volume_24h': 281699902.15760195},
#  {'basis': 0.0157943,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.005238,
#   'index': 0.25069959,
#   'index_id': 'XLM',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 47837021.72,
#   'price': '0.25',
#   'price_percentage_change_24h': -0.3656888,
#   'spread': 0.02,
#   'symbol': 'XLMUSDT',
#   'volume_24h': 89087840.76860175},
#  {'basis': -0.080429,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.7454,
#   'index_id': 'KXRPUSD',
#   'last_traded_at': 1642518443,
#   'market': 'KuCoin Futures',
#   'open_interest': 47625132.36,
#   'price': '0.75',
#   'price_percentage_change_24h': -1.9324307,
#   'spread': 0.01,
#   'symbol': 'XRPUSDM',
#   'volume_24h': 5398032.0},
#  {'basis': 0.12361111111111112,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.45043068,
#   'index_id': 'ADA',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 47250750.0,
#   'price': '1.45',
#   'price_percentage_change_24h': -4.33915541321359,
#   'spread': 0.01,
#   'symbol': 'ADAUSD_PERP',
#   'volume_24h': 533179725.9383825},
#  {'basis': 0.041222234168368996,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 27.91450224,
#   'index_id': 'FIL',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 46872905.19,
#   'price': '27.98',
#   'price_percentage_change_24h': -4.477765225428777,
#   'spread': 0.02,
#   'symbol': 'FILUSDT',
#   'volume_24h': 136648863.9835217},
#  {'basis': 0.07980818114511352,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 16.22093531,
#   'index_id': 'UNI',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 46169253.99,
#   'price': '16.25',
#   'price_percentage_change_24h': -1.6803154382772216,
#   'spread': 0.04,
#   'symbol': 'UNIUSDT',
#   'volume_24h': 193738121.92646974},
#  {'basis': 0.052873248832555036,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.002575,
#   'index': 4.49937771,
#   'index_id': 'CRV',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 45316894.94,
#   'price': '4.51',
#   'price_percentage_change_24h': -9.334677419354838,
#   'spread': 0.02,
#   'symbol': 'CRVUSDT',
#   'volume_24h': 283241305.9161216},
#  {'basis': 0.07370630512904279,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 6.1265123,
#   'index_id': 'SUSHI',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 45284078.83,
#   'price': '6.14',
#   'price_percentage_change_24h': -7.494711393170142,
#   'spread': 0.03,
#   'symbol': 'SUSHIUSDT',
#   'volume_24h': 188427869.2020959},
#  {'basis': 0.01792237004706439,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 380.39816415,
#   'index_id': 'BCH',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 45041910.36,
#   'price': '381.38',
#   'price_percentage_change_24h': 0.8137623919843079,
#   'spread': 0.02,
#   'symbol': 'BCHUSDT',
#   'volume_24h': 171923580.36453548},
#  {'basis': 0.0646217,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.30501698,
#   'index_id': 'ONE',
#   'last_traded_at': 1642518456,
# ...
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 6860.91,
#   'price': '0.16',
#   'price_percentage_change_24h': -3.2863011,
#   'spread': 0.31,
#   'symbol': 'DOGE-USD-SWAP-LIN',
#   'volume_24h': 52201.683},
#  {'basis': 0.3197536712458432,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.08471,
#   'index_id': 'IRIS',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 6833.83,
#   'price': '0.08',
#   'price_percentage_change_24h': -9.6608537,
#   'spread': 100.0,
#   'symbol': 'IRIS_USDT',
#   'volume_24h': 21254.552106464922},
#  {'basis': 0.004864996351252737,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0002,
#   'index': 2055.6,
#   'index_id': 'MKR',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 6719.64,
#   'price': '2055.5',
#   'price_percentage_change_24h': -2.6060175313906657,
#   'spread': 0.62,
#   'symbol': 'MKR-USD-SWAP-LIN',
#   'volume_24h': 146141.1168},
#  {'basis': 0.09211833364538476,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.018682,
#   'index': 1069.18400804,
#   'index_id': 'BTCDOM',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': 6159.07,
#   'price': '1071.15',
#   'price_percentage_change_24h': 1.0309278350515463,
#   'spread': 0.02,
#   'symbol': 'BTCDOMUSDT',
#   'volume_24h': 10175762.014460571},
#  {'basis': 0.21063281053759306,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 1823.983833101,
#   'index_id': 'XAUTPFC',
#   'last_traded_at': 1642517676,
#   'market': 'BTSE (Futures)',
#   'open_interest': 6147.74,
#   'price': '1820.15',
#   'price_percentage_change_24h': -0.3667515121657498,
#   'spread': 0.02,
#   'symbol': 'XAUTPFC',
#   'volume_24h': 5847.37995},
#  {'basis': 0.06720412865410633,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3114.001332,
#   'index_id': 'USD',
#   'last_traded_at': 1642517986,
#   'market': 'Bitget Futures',
#   'open_interest': 5684.5,
#   'price': '3111.91',
#   'price_percentage_change_24h': -3.1073789352089696,
#   'spread': 0.02,
#   'symbol': 'ETHUSD_DMCBL',
#   'volume_24h': 86894324.354},
#  {'basis': -0.05282955073750053,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3310.79,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517970,
#   'market': 'Crypto.com Exchange (Futures)',
#   'open_interest': 4939.99,
#   'price': '3114.58',
#   'price_percentage_change_24h': -3.663149820136653,
#   'spread': 0.18,
#   'symbol': 'ETHUSD-220128',
#   'volume_24h': 22712.763192},
#  {'basis': -0.6378269555768301,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3227.81,
#   'index_id': 'ETH',
#   'last_traded_at': 1642517968,
#   'market': 'Crypto.com Exchange (Futures)',
#   'open_interest': 4833.49,
#   'price': '3129.45',
#   'price_percentage_change_24h': -3.665658005313172,
#   'spread': 0.06,
#   'symbol': 'ETHUSD-220225',
#   'volume_24h': 4703.250405},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0002,
#   'index': 0.11896,
#   'index_id': 'REVV',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 4764.23,
#   'price': '0.12',
#   'price_percentage_change_24h': -3.4650653,
#   'spread': 1.67,
#   'symbol': 'REVV-USD-SWAP-LIN',
#   'volume_24h': 114338.64192},
#  {'basis': 0.32238907270721984,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 1.1825,
#   'index_id': 'HIVE',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 3963.45,
#   'price': '1.18',
#   'price_percentage_change_24h': -6.459804777398619,
#   'spread': 8.33,
#   'symbol': 'HIVE_USDT',
#   'volume_24h': 6579.266593553361},
#  {'basis': 8.301253867448299,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 33.2539,
#   'index_id': 'ETC',
#   'last_traded_at': 1642498455,
#   'market': 'Gate.io (Futures)',
#   'open_interest': 3718.03,
#   'price': '30.71',
#   'price_percentage_change_24h': -4.9969059405940595,
#   'spread': 20.27,
#   'symbol': 'ETC_USD',
#   'volume_24h': 122.82},
#  {'basis': -0.09352205210918114,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 40.262310613,
#   'index_id': 'BDIPFC',
#   'last_traded_at': 1642517676,
#   'market': 'BTSE (Futures)',
#   'open_interest': 3249.17,
#   'price': '40.3',
#   'price_percentage_change_24h': -0.0496031746031746,
#   'spread': 0.3,
#   'symbol': 'BDIPFC',
#   'volume_24h': 31136.3147},
#  {'basis': 0.020279862096937742,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0002,
#   'index': 4.932,
#   'index_id': 'SNX',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 2941.83,
#   'price': '4.93',
#   'price_percentage_change_24h': -1.0832497492477433,
#   'spread': 0.61,
#   'symbol': 'SNX-USD-SWAP-LIN',
#   'volume_24h': 70592.196},
#  {'basis': 0.037478185332449745,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 1.358608991235,
#   'index_id': 'GBP',
#   'last_traded_at': 1642517971,
#   'market': 'Bitfinex (Futures)',
#   'open_interest': 2277.73,
#   'price': '1.36',
#   'price_percentage_change_24h': -0.5054945054945055,
#   'spread': 0.02,
#   'symbol': 'GBPF0:USTF0',
#   'volume_24h': 7452.6285411864},
#  {'basis': 0.0656104609436356,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41409.651249,
#   'index_id': 'USD',
#   'last_traded_at': 1642517985,
#   'market': 'Bitget Futures',
#   'open_interest': 2077.8,
#   'price': '41382.5',
#   'price_percentage_change_24h': -1.9592745708904393,
#   'spread': 0.01,
#   'symbol': 'BTCUSD_DMCBL',
#   'volume_24h': 535217206.248},
#  {'basis': -0.01725923369002416,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0002,
#   'index': 5.793,
#   'index_id': 'OMG',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 1616.99,
#   'price': '5.79',
#   'price_percentage_change_24h': -4.688271097219937,
#   'spread': 0.79,
#   'symbol': 'OMG-USD-SWAP-LIN',
#   'volume_24h': 27346.75296},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0002,
#   'index': 15.48,
#   'index_id': 'BAL',
#   'last_traded_at': 1642518003,
#   'market': 'CoinFLEX (Futures)',
#   'open_interest': 1535.0,
#   'price': '15.48',
#   'price_percentage_change_24h': -5.896656534954407,
#   'spread': 0.23,
#   'symbol': 'BAL-USD-SWAP-LIN',
#   'volume_24h': 35301.366},
#  {'basis': -1.2620403913518292,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.00999999999995,
#   'index': 0.161930253758183,
#   'index_id': 'DOGE',
#   'last_traded_at': 1642516915,
#   'market': 'MCS',
#   'open_interest': 1423.23,
#   'price': '0.16',
#   'price_percentage_change_24h': -2.5549614,
#   'spread': 0.61,
#   'symbol': 'DOGEUSDT_QUANTO_PERP',
#   'volume_24h': 39.53889357344562},
#  {'basis': 0.3470186774356386,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 3.97574888,
#   'index_id': 'XTZPFC',
#   'last_traded_at': 1642517676,
#   'market': 'BTSE (Futures)',
#   'open_interest': 627.7,
#   'price': '3.96',
#   'price_percentage_change_24h': -3.741496598639456,
#   'spread': 0.35,
#   'symbol': 'XTZPFC',
#   'volume_24h': 1720.86695},
#  {'basis': -0.13453770197486534,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.01,
#   'index': 378.250425,
#   'index_id': 'USD',
#   'last_traded_at': 1642517985,
#   'market': 'Bitget Futures',
#   'open_interest': 417.44,
#   'price': '378.76',
#   'price_percentage_change_24h': 0.29657875225082087,
#   'spread': 0.07,
#   'symbol': 'BCHUSD_DMCBL',
#   'volume_24h': 3113969.5278},
#  {'basis': -0.04127222489187891,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 41602.8225,
#   'index_id': 'BTC',
#   'last_traded_at': 1642518438,
#   'market': 'BTCEX (Futures)',
#   'open_interest': None,
#   'price': '41735.06',
#   'price_percentage_change_24h': -2.2465444552746234,
#   'spread': 2.05,
#   'symbol': 'BTC-USDT-PERPETUAL',
#   'volume_24h': 3680195324.895129},
#  {'basis': -0.07502404616864379,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3116.66,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518005,
#   'market': 'Gate.io (Futures)',
#   'open_interest': None,
#   'price': '3124.49',
#   'price_percentage_change_24h': -3.9716748768472905,
#   'spread': 0.01,
#   'symbol': 'ETH_USDT',
#   'volume_24h': 1385024911.5017753},
#  {'basis': 0.0516825360588737,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 31555.0,
#   'index_id': 'YFI',
#   'last_traded_at': 1642518438,
#   'market': 'BTCEX (Futures)',
#   'open_interest': None,
#   'price': '31625.89',
#   'price_percentage_change_24h': -1.0401566353521472,
#   'spread': 6.16,
#   'symbol': 'YFI-USDT-PERPETUAL',
#   'volume_24h': 403363042.025086},
#  {'basis': 0.11934468916133233,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0192,
#   'index': 2.7684,
#   'index_id': 'FTM',
#   'last_traded_at': 1642518719,
#   'market': 'FTX (Derivatives)',
#   'open_interest': None,
#   'price': '2.77',
#   'price_percentage_change_24h': -11.693413173652695,
#   'spread': 0.01,
#   'symbol': 'FTM-PERP',
#   'volume_24h': 372293332.67795},
#  {'basis': 0.13204847584812177,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0288,
#   'index': 76.63606330099036,
#   'index_id': 'LUNA',
#   'last_traded_at': 1642518720,
#   'market': 'FTX (Derivatives)',
#   'open_interest': None,
#   'price': '76.54',
#   'price_percentage_change_24h': -6.141544951743252,
#   'spread': 0.02,
#   'symbol': 'LUNA-PERP',
#   'volume_24h': 353248309.758},
#  {'basis': -0.0481691,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.46565559,
#   'index_id': 'ROSE',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': None,
#   'price': '0.47',
#   'price_percentage_change_24h': -12.0815248,
#   'spread': 0.02,
#   'symbol': 'ROSEUSDT',
#   'volume_24h': 336215292.56345457},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.004,
#   'index': 41379.5,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517807,
#   'market': 'Stormgain Futures',
#   'open_interest': None,
#   'price': '41505.22',
#   'price_percentage_change_24h': -2.934518713127925,
#   'spread': 0.05,
#   'symbol': 'BTC-PERPUSDT',
#   'volume_24h': 326887506.2129526},
#  {'basis': -0.18680644590230705,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.024,
#   'index': 17.154394510175,
#   'index_id': 'NEAR',
#   'last_traded_at': 1642518715,
#   'market': 'FTX (Derivatives)',
#   'open_interest': None,
#   'price': '17.19',
#   'price_percentage_change_24h': -9.066137566137566,
#   'spread': 0.01,
#   'symbol': 'NEAR-PERP',
#   'volume_24h': 281164322.53655},
#  {'basis': 0.07072350580323246,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.004,
#   'index': 461.276,
#   'index_id': 'BNB',
#   'last_traded_at': 1642518003,
#   'market': 'Bitforex (Futures)',
#   'open_interest': None,
#   'price': '460.95',
#   'price_percentage_change_24h': -2.1337579617834397,
#   'spread': 0.01,
#   'symbol': 'SWAP-USD-BNB',
#   'volume_24h': 257941046.0},
#  {'basis': -0.05045045045045045,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.017,
#   'index': 2.7736,
#   'index_id': 'EOS',
#   'last_traded_at': 1642518003,
#   'market': 'Bitforex (Futures)',
#   'open_interest': None,
#   'price': '2.78',
#   'price_percentage_change_24h': -2.288732394366197,
#   'spread': 0.04,
#   'symbol': 'SWAP-USD-EOS',
#   'volume_24h': 225570645.0},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': None,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517805,
#   'market': 'Bitflyer (Futures)',
#   'open_interest': None,
#   'price': '42418.26',
#   'price_percentage_change_24h': -3.0149335703265816,
#   'spread': 0.01,
#   'symbol': 'FX_BTC_JPY',
#   'volume_24h': 220978557.24191985},
#  {'basis': 0.0,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': None,
#   'index_id': 'BTC',
#   'last_traded_at': 1642517804,
#   'market': 'GMO Japan (Futures)',
#   'open_interest': None,
#   'price': '41398.17',
#   'price_percentage_change_24h': -2.717705667069664,
#   'spread': 0.04,
#   'symbol': 'BTC_JPY',
#   'volume_24h': 195819549.93012145},
#  {'basis': -0.03245962833725554,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.0,
#   'index': 24.638,
#   'index_id': 'DOT',
#   'last_traded_at': 1642518447,
#   'market': 'Hopex',
#   'open_interest': None,
#   'price': '24.71',
#   'price_percentage_change_24h': -5.769451347734659,
#   'spread': None,
#   'symbol': 'DOTUSDT',
#   'volume_24h': 192258550.24817017},
#  {'basis': -0.1556746532156526,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.06334124,
#   'index_id': 'PEOPLE',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': None,
#   'price': '0.06',
#   'price_percentage_change_24h': -12.6531736,
#   'spread': 0.05,
#   'symbol': 'PEOPLEUSDT',
#   'volume_24h': 184706433.51566604},
#  {'basis': -0.1161701,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 0.86732126,
#   'index_id': 'DUSK',
#   'last_traded_at': 1642518456,
#   'market': 'Binance (Futures)',
#   'open_interest': None,
#   'price': '0.87',
#   'price_percentage_change_24h': -17.441075520313376,
#   'spread': 0.01,
#   'symbol': 'DUSKUSDT',
#   'volume_24h': 135300920.19437292},
#  {'basis': 0.0440529,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': -0.043,
#   'index': 0.06813,
#   'index_id': 'TRX',
#   'last_traded_at': 1642518003,
#   'market': 'Bitforex (Futures)',
#   'open_interest': None,
#   'price': '0.07',
#   'price_percentage_change_24h': -3.8814397,
#   'spread': 0.15,
#   'symbol': 'SWAP-USD-TRX',
#   'volume_24h': 129799803.0},
#  {'basis': -0.17005504987191367,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.016,
#   'index': 36.6316,
#   'index_id': 'ATOM',
#   'last_traded_at': 1642518004,
#   'market': 'Bitforex (Futures)',
#   'open_interest': None,
#   'price': '36.69',
#   'price_percentage_change_24h': -10.754937250705321,
#   'spread': 0.07,
#   'symbol': 'SWAP-USD-ATOM',
#   'volume_24h': 125161780.0},
#  {'basis': 0.0998284858600015,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 46997.3699732537,
#   'index_id': 'DEXBTUSDT',
#   'last_traded_at': 1642517803,
#   'market': 'Delta Exchange (Futures)',
#   'open_interest': None,
#   'price': '41477.64',
#   'price_percentage_change_24h': -2.588867164495536,
#   'spread': 0.01,
#   'symbol': 'BTCUSDT',
#   'volume_24h': 109705454.1880372},
#  {'basis': 0.006381030153559499,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.01,
#   'index': 3134.48999999,
#   'index_id': 'ETH',
#   'last_traded_at': 1642518439,
#   'market': 'BTCEX (Futures)',
#   'open_interest': None,
#   'price': '3142.95',
#   'price_percentage_change_24h': -3.231592856966434,
#   'spread': 6.06,
#   'symbol': 'ETH-USDT-PERPETUAL',
#   'volume_24h': 108753262.75570112},
#  {'basis': 0.0488035,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.029873,
#   'index': 0.063551,
#   'index_id': 'OkexSwap-PEOPLE',
#   'last_traded_at': 1642518008,
#   'market': 'OKEx (Futures)',
#   'open_interest': None,
#   'price': '0.06',
#   'price_percentage_change_24h': -12.7691883,
#   'spread': 0.02,
#   'symbol': 'PEOPLE-USDT-SWAP',
#   'volume_24h': 108332069.09360199},
#  {'basis': -0.0662372511457402,
#   'contract_type': 'perpetual',
#   'expired_at': None,
#   'funding_rate': 0.072,
#   'index': 0.3084955256057131,
#   'index_id': 'ONE',
#   'last_traded_at': 1642518712,
#   'market': 'FTX (Derivatives)',
#   'open_interest': None,
#   'price': '0.31',
#   'price_percentage_change_24h': -5.7116677,
#   'spread': 0.04,
#   'symbol': 'ONE-PERP',
#   'volume_24h': 104818420.682},
#  ...]

# %%
cg.get_events()
# Out:
# {'count': 0, 'data': [], 'page': 1}

# %%
cg.get_exchange_rates()
# Out:
# {'rates': {'aed': {'name': 'United Arab Emirates Dirham',
#    'type': 'fiat',
#    'unit': 'DH',
#    'value': 152932.338},
#   'ars': {'name': 'Argentine Peso',
#    'type': 'fiat',
#    'unit': '$',
#    'value': 4337937.974},
#   'aud': {'name': 'Australian Dollar',
#    'type': 'fiat',
#    'unit': 'A$',
#    'value': 57934.666},
#   'bch': {'name': 'Bitcoin Cash',
#    'type': 'crypto',
#    'unit': 'BCH',
#    'value': 109.242},
#   'bdt': {'name': 'Bangladeshi Taka',
#    'type': 'fiat',
#    'unit': '৳',
#    'value': 3580393.694},
#   'bhd': {'name': 'Bahraini Dinar',
#    'type': 'fiat',
#    'unit': 'BD',
#    'value': 15695.154},
#   'bits': {'name': 'Bits',
#    'type': 'crypto',
#    'unit': 'μBTC',
#    'value': 1000000.0},
#   'bmd': {'name': 'Bermudian Dollar',
#    'type': 'fiat',
#    'unit': '$',
#    'value': 41636.901},
#   'bnb': {'name': 'Binance Coin',
#    'type': 'crypto',
#    'unit': 'BNB',
#    'value': 89.833},
#   'brl': {'name': 'Brazil Real',
#    'type': 'fiat',
#    'unit': 'R$',
#    'value': 230093.843},
#   'btc': {'name': 'Bitcoin', 'type': 'crypto', 'unit': 'BTC', 'value': 1.0},
#   'cad': {'name': 'Canadian Dollar',
#    'type': 'fiat',
#    'unit': 'CA$',
#    'value': 52129.858},
#   'chf': {'name': 'Swiss Franc',
#    'type': 'fiat',
#    'unit': 'Fr.',
#    'value': 38158.637},
#   'clp': {'name': 'Chilean Peso',
#    'type': 'fiat',
#    'unit': 'CLP$',
#    'value': 34270917.041},
#   'cny': {'name': 'Chinese Yuan',
#    'type': 'fiat',
#    'unit': '¥',
#    'value': 264535.888},
#   'czk': {'name': 'Czech Koruna',
#    'type': 'fiat',
#    'unit': 'Kč',
#    'value': 895605.248},
#   'dkk': {'name': 'Danish Krone',
#    'type': 'fiat',
#    'unit': 'kr.',
#    'value': 272896.245},
#   'dot': {'name': 'Polkadot',
#    'type': 'crypto',
#    'unit': 'DOT',
#    'value': 1684.477},
#   'eos': {'name': 'EOS', 'type': 'crypto', 'unit': 'EOS', 'value': 14855.698},
#   'eth': {'name': 'Ether', 'type': 'crypto', 'unit': 'ETH', 'value': 13.255},
#   'eur': {'name': 'Euro', 'type': 'fiat', 'unit': '€', 'value': 36667.495},
#   'gbp': {'name': 'British Pound Sterling',
#    'type': 'fiat',
#    'unit': '£',
#    'value': 30655.459},
#   'hkd': {'name': 'Hong Kong Dollar',
#    'type': 'fiat',
#    'unit': 'HK$',
#    'value': 324429.113},
#   'huf': {'name': 'Hungarian Forint',
#    'type': 'fiat',
#    'unit': 'Ft',
#    'value': 13117595.814},
#   'idr': {'name': 'Indonesian Rupiah',
#    'type': 'fiat',
#    'unit': 'Rp',
#    'value': 597659969.574},
#   'ils': {'name': 'Israeli New Shekel',
#    'type': 'fiat',
#    'unit': '₪',
#    'value': 130520.859},
#   'inr': {'name': 'Indian Rupee',
#    'type': 'fiat',
#    'unit': '₹',
#    'value': 3104613.529},
#   'jpy': {'name': 'Japanese Yen',
#    'type': 'fiat',
#    'unit': '¥',
#    'value': 4770513.262},
#   'krw': {'name': 'South Korean Won',
#    'type': 'fiat',
#    'unit': '₩',
#    'value': 49646130.469},
#   'kwd': {'name': 'Kuwaiti Dinar',
#    'type': 'fiat',
#    'unit': 'KD',
#    'value': 12590.166},
#   'link': {'name': 'Chainlink',
#    'type': 'crypto',
#    'unit': 'LINK',
#    'value': 1827.249},
#   'lkr': {'name': 'Sri Lankan Rupee',
#    'type': 'fiat',
#    'unit': 'Rs',
#    'value': 8433032.219},
#   'ltc': {'name': 'Litecoin',
#    'type': 'crypto',
#    'unit': 'LTC',
#    'value': 295.865},
#   'mmk': {'name': 'Burmese Kyat',
#    'type': 'fiat',
#    'unit': 'K',
#    'value': 74044225.611},
#   'mxn': {'name': 'Mexican Peso',
#    'type': 'fiat',
#    'unit': 'MX$',
#    'value': 848565.46},
#   'myr': {'name': 'Malaysian Ringgit',
#    'type': 'fiat',
#    'unit': 'RM',
#    'value': 174187.976},
#   'ngn': {'name': 'Nigerian Naira',
#    'type': 'fiat',
#    'unit': '₦',
#    'value': 17258495.563},
#   'nok': {'name': 'Norwegian Krone',
#    'type': 'fiat',
#    'unit': 'kr',
#    'value': 365964.67},
#   'nzd': {'name': 'New Zealand Dollar',
#    'type': 'fiat',
#    'unit': 'NZ$',
#    'value': 61473.137},
#   'php': {'name': 'Philippine Peso',
#    'type': 'fiat',
#    'unit': '₱',
#    'value': 2143238.672},
#   'pkr': {'name': 'Pakistani Rupee',
#    'type': 'fiat',
#    'unit': '₨',
#    'value': 7334340.153},
#   'pln': {'name': 'Polish Zloty',
#    'type': 'fiat',
#    'unit': 'zł',
#    'value': 166186.279},
#   'rub': {'name': 'Russian Ruble',
#    'type': 'fiat',
#    'unit': '₽',
#    'value': 3191765.142},
#   'sar': {'name': 'Saudi Riyal',
#    'type': 'fiat',
#    'unit': 'SR',
#    'value': 156216.282},
#   'sats': {'name': 'Satoshi',
#    'type': 'crypto',
#    'unit': 'sats',
#    'value': 100000000.0},
#   'sek': {'name': 'Swedish Krona',
#    'type': 'fiat',
#    'unit': 'kr',
#    'value': 379051.398},
#   'sgd': {'name': 'Singapore Dollar',
#    'type': 'fiat',
#    'unit': 'S$',
#    'value': 56212.148},
#   'thb': {'name': 'Thai Baht',
#    'type': 'fiat',
#    'unit': '฿',
#    'value': 1378264.704},
#   'try': {'name': 'Turkish Lira',
#    'type': 'fiat',
#    'unit': '₺',
#    'value': 567937.95},
#   'twd': {'name': 'New Taiwan Dollar',
#    'type': 'fiat',
#    'unit': 'NT$',
#    'value': 1149603.17},
#   'uah': {'name': 'Ukrainian hryvnia',
#    'type': 'fiat',
#    'unit': '₴',
#    'value': 1185059.948},
#   'usd': {'name': 'US Dollar',
#    'type': 'fiat',
#    'unit': '$',
#    'value': 41636.901},
#   'vef': {'name': 'Venezuelan bolívar fuerte',
#    'type': 'fiat',
#    'unit': 'Bs.F',
#    'value': 4169.102},
#   'vnd': {'name': 'Vietnamese đồng',
#    'type': 'fiat',
#    'unit': '₫',
#    'value': 947585568.185},
#   'xag': {'name': 'Silver - Troy Ounce',
#    'type': 'commodity',
#    'unit': 'XAG',
#    'value': 1777.799},
#   'xau': {'name': 'Gold - Troy Ounce',
#    'type': 'commodity',
#    'unit': 'XAU',
#    'value': 22.912},
#   'xdr': {'name': 'IMF Special Drawing Rights',
#    'type': 'fiat',
#    'unit': 'XDR',
#    'value': 29598.007},
#   'xlm': {'name': 'Lumens',
#    'type': 'crypto',
#    'unit': 'XLM',
#    'value': 164911.486},
#   'xrp': {'name': 'XRP', 'type': 'crypto', 'unit': 'XRP', 'value': 55753.121},
#   'yfi': {'name': 'Yearn.finance',
#    'type': 'crypto',
#    'unit': 'YFI',
#    'value': 1.312},
#   'zar': {'name': 'South African Rand',
#    'type': 'fiat',
#    'unit': 'R',
#    'value': 642746.054}}}

# %%
cg.get_search_trending()
# Out:
# {'coins': [{'item': {'coin_id': 7588,
#     'id': 'telos',
#     'large': 'https://assets.coingecko.com/coins/images/7588/large/TLOS_200.png?1629277084',
#     'market_cap_rank': 340,
#     'name': 'Telos',
#     'price_btc': 1.6445214745788076e-05,
#     'score': 0,
#     'slug': 'telos',
#     'small': 'https://assets.coingecko.com/coins/images/7588/small/TLOS_200.png?1629277084',
#     'symbol': 'TLOS',
#     'thumb': 'https://assets.coingecko.com/coins/images/7588/thumb/TLOS_200.png?1629277084'}},
#   {'item': {'coin_id': 10366,
#     'id': 'smooth-love-potion',
#     'large': 'https://assets.coingecko.com/coins/images/10366/large/SLP.png?1578640057',
#     'market_cap_rank': 167,
#     'name': 'Smooth Love Potion',
#     'price_btc': 4.3564447714683035e-07,
#     'score': 1,
#     'slug': 'smooth-love-potion',
#     'small': 'https://assets.coingecko.com/coins/images/10366/small/SLP.png?1578640057',
#     'symbol': 'SLP',
#     'thumb': 'https://assets.coingecko.com/coins/images/10366/thumb/SLP.png?1578640057'}},
#   {'item': {'coin_id': 18126,
#     'id': 'wonderland',
#     'large': 'https://assets.coingecko.com/coins/images/18126/large/time.PNG?1630621941',
#     'market_cap_rank': 101,
#     'name': 'Wonderland',
#     'price_btc': 0.031094290458259153,
#     'score': 2,
#     'slug': 'wonderland',
#     'small': 'https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941',
#     'symbol': 'TIME',
#     'thumb': 'https://assets.coingecko.com/coins/images/18126/thumb/time.PNG?1630621941'}},
#   {'item': {'coin_id': 20805,
#     'id': 'symbiosis-finance',
#     'large': 'https://assets.coingecko.com/coins/images/20805/large/SymbiosisFinance_logo-150x150.jpeg?1637707064',
#     'market_cap_rank': 694,
#     'name': 'Symbiosis Finance',
#     'price_btc': 0.00010475400977602508,
#     'score': 3,
#     'slug': 'symbiosis-finance',
#     'small': 'https://assets.coingecko.com/coins/images/20805/small/SymbiosisFinance_logo-150x150.jpeg?1637707064',
#     'symbol': 'SIS',
#     'thumb': 'https://assets.coingecko.com/coins/images/20805/thumb/SymbiosisFinance_logo-150x150.jpeg?1637707064'}},
#   {'item': {'coin_id': 14483,
#     'id': 'olympus',
#     'large': 'https://assets.coingecko.com/coins/images/14483/large/token_OHM_%281%29.png?1628311611',
#     'market_cap_rank': 113,
#     'name': 'Olympus',
#     'price_btc': 0.0026607809597811085,
#     'score': 4,
#     'slug': 'olympus',
#     'small': 'https://assets.coingecko.com/coins/images/14483/small/token_OHM_%281%29.png?1628311611',
#     'symbol': 'OHM',
#     'thumb': 'https://assets.coingecko.com/coins/images/14483/thumb/token_OHM_%281%29.png?1628311611'}},
#   {'item': {'coin_id': 4001,
#     'id': 'fantom',
#     'large': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#     'market_cap_rank': 27,
#     'name': 'Fantom',
#     'price_btc': 6.592422799442819e-05,
#     'score': 5,
#     'slug': 'fantom',
#     'small': 'https://assets.coingecko.com/coins/images/4001/small/Fantom.png?1558015016',
#     'symbol': 'FTM',
#     'thumb': 'https://assets.coingecko.com/coins/images/4001/thumb/Fantom.png?1558015016'}},
#   {'item': {'coin_id': 17332,
#     'id': 'splinterlands',
#     'large': 'https://assets.coingecko.com/coins/images/17332/large/splinter.PNG?1627339560',
#     'market_cap_rank': 620,
#     'name': 'Splinterlands',
#     'price_btc': 3.5229498376766468e-06,
#     'score': 6,
#     'slug': 'splinterlands',
#     'small': 'https://assets.coingecko.com/coins/images/17332/small/splinter.PNG?1627339560',
#     'symbol': 'SPS',
#     'thumb': 'https://assets.coingecko.com/coins/images/17332/thumb/splinter.PNG?1627339560'}}],
#  'exchanges': []}

# %%
import pandas as pd
import json
json_search_trending = cg.get_search_trending()

# %%
dfSearchTrending = pd.read_json(dados_json_search_trending )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d05f3aeac30f> in <module>()
# ----> 1 dfSearchTrending = pd.read_json(dados_json_search_trending )
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     592     compression = infer_compression(path_or_buf, compression)
#     593     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 594         path_or_buf, encoding=encoding, compression=compression
#     595     )
#     596
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     220         try:
#     221             file_obj = fsspec.open(
# --> 222                 filepath_or_buffer, mode=mode or "rb", **(storage_options or {})
#     223             ).open()
#     224         # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#
# /usr/local/lib/python3.7/dist-packages/fsspec/core.py in open(urlpath, mode, compression, encoding, errors, protocol, newline, **kwargs)
#     463         newline=newline,
#     464         expand=False,
# --> 465         **kwargs,
#     466     )[0]
#     467
#
# /usr/local/lib/python3.7/dist-packages/fsspec/core.py in open_files(urlpath, mode, compression, encoding, errors, name_function, num, protocol, newline, auto_mkdir, expand, **kwargs)
#     293         storage_options=kwargs,
#     294         protocol=protocol,
# --> 295         expand=expand,
#     296     )
#     297     if "r" not in mode and auto_mkdir:
#
# /usr/local/lib/python3.7/dist-packages/fsspec/core.py in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol, expand)
#     624                         "share the same protocol"
#     625                     )
# --> 626             cls = get_filesystem_class(protocol)
#     627             optionss = list(map(cls._get_kwargs_from_urls, urlpath))
#     628             paths = [cls._strip_protocol(u) for u in urlpath]
#
# /usr/local/lib/python3.7/dist-packages/fsspec/registry.py in get_filesystem_class(protocol)
#     214     if protocol not in registry:
#     215         if protocol not in known_implementations:
# --> 216             raise ValueError("Protocol not known: %s" % protocol)
#     217         bit = known_implementations[protocol]
#     218         try:
#
# ValueError: Protocol not known: {"coins": [{"item": {"id": "utrust", "coin_id": 1824, "name": "Utrust", "symbol": "UTK", "market_cap_rank": 350, "thumb": "https

# %%
# !pip install fsspec
# Out:
# Collecting fsspec
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 14.5 MB/s
# Installing collected packages: fsspec
# Successfully installed fsspec-2022.1.0

# %%
dados_json_search_trending = json.dumps(json_search_trending)

# %%
json_search_trending
# Out:
# {'coins': [{'item': {'coin_id': 7588,
#     'id': 'telos',
#     'large': 'https://assets.coingecko.com/coins/images/7588/large/TLOS_200.png?1629277084',
#     'market_cap_rank': 340,
#     'name': 'Telos',
#     'price_btc': 1.6445214745788076e-05,
#     'score': 0,
#     'slug': 'telos',
#     'small': 'https://assets.coingecko.com/coins/images/7588/small/TLOS_200.png?1629277084',
#     'symbol': 'TLOS',
#     'thumb': 'https://assets.coingecko.com/coins/images/7588/thumb/TLOS_200.png?1629277084'}},
#   {'item': {'coin_id': 10366,
#     'id': 'smooth-love-potion',
#     'large': 'https://assets.coingecko.com/coins/images/10366/large/SLP.png?1578640057',
#     'market_cap_rank': 167,
#     'name': 'Smooth Love Potion',
#     'price_btc': 4.3564447714683035e-07,
#     'score': 1,
#     'slug': 'smooth-love-potion',
#     'small': 'https://assets.coingecko.com/coins/images/10366/small/SLP.png?1578640057',
#     'symbol': 'SLP',
#     'thumb': 'https://assets.coingecko.com/coins/images/10366/thumb/SLP.png?1578640057'}},
#   {'item': {'coin_id': 18126,
#     'id': 'wonderland',
#     'large': 'https://assets.coingecko.com/coins/images/18126/large/time.PNG?1630621941',
#     'market_cap_rank': 101,
#     'name': 'Wonderland',
#     'price_btc': 0.031094290458259153,
#     'score': 2,
#     'slug': 'wonderland',
#     'small': 'https://assets.coingecko.com/coins/images/18126/small/time.PNG?1630621941',
#     'symbol': 'TIME',
#     'thumb': 'https://assets.coingecko.com/coins/images/18126/thumb/time.PNG?1630621941'}},
#   {'item': {'coin_id': 20805,
#     'id': 'symbiosis-finance',
#     'large': 'https://assets.coingecko.com/coins/images/20805/large/SymbiosisFinance_logo-150x150.jpeg?1637707064',
#     'market_cap_rank': 694,
#     'name': 'Symbiosis Finance',
#     'price_btc': 0.00010475400977602508,
#     'score': 3,
#     'slug': 'symbiosis-finance',
#     'small': 'https://assets.coingecko.com/coins/images/20805/small/SymbiosisFinance_logo-150x150.jpeg?1637707064',
#     'symbol': 'SIS',
#     'thumb': 'https://assets.coingecko.com/coins/images/20805/thumb/SymbiosisFinance_logo-150x150.jpeg?1637707064'}},
#   {'item': {'coin_id': 14483,
#     'id': 'olympus',
#     'large': 'https://assets.coingecko.com/coins/images/14483/large/token_OHM_%281%29.png?1628311611',
#     'market_cap_rank': 113,
#     'name': 'Olympus',
#     'price_btc': 0.0026607809597811085,
#     'score': 4,
#     'slug': 'olympus',
#     'small': 'https://assets.coingecko.com/coins/images/14483/small/token_OHM_%281%29.png?1628311611',
#     'symbol': 'OHM',
#     'thumb': 'https://assets.coingecko.com/coins/images/14483/thumb/token_OHM_%281%29.png?1628311611'}},
#   {'item': {'coin_id': 4001,
#     'id': 'fantom',
#     'large': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#     'market_cap_rank': 27,
#     'name': 'Fantom',
#     'price_btc': 6.592422799442819e-05,
#     'score': 5,
#     'slug': 'fantom',
#     'small': 'https://assets.coingecko.com/coins/images/4001/small/Fantom.png?1558015016',
#     'symbol': 'FTM',
#     'thumb': 'https://assets.coingecko.com/coins/images/4001/thumb/Fantom.png?1558015016'}},
#   {'item': {'coin_id': 17332,
#     'id': 'splinterlands',
#     'large': 'https://assets.coingecko.com/coins/images/17332/large/splinter.PNG?1627339560',
#     'market_cap_rank': 620,
#     'name': 'Splinterlands',
#     'price_btc': 3.5229498376766468e-06,
#     'score': 6,
#     'slug': 'splinterlands',
#     'small': 'https://assets.coingecko.com/coins/images/17332/small/splinter.PNG?1627339560',
#     'symbol': 'SPS',
#     'thumb': 'https://assets.coingecko.com/coins/images/17332/thumb/splinter.PNG?1627339560'}}],
#  'exchanges': []}

# %%
dfSearchTrending.head()
# Out:
#                                                            0  ...                                                  6
# coins      {'item': {'id': 'telos', 'coin_id': 7588, 'nam...  ...  {'item': {'id': 'splinterlands', 'coin_id': 17...
# exchanges                                               None  ...                                               None
#
# [2 rows x 7 columns]

# %% [markdown]
# <h1>O que é o Colab?</h1>
#
# O Colab, ou "Colaboratory", permite escrever e executar Python no navegador e conta com o seguinte:
# - Nenhuma configuração necessária
# - Acesso gratuito a GPUs
# - Compartilhamento fácil
#
# Você pode ser um <strong>estudante</strong>, um <strong>cientista de dados</strong> ou um <strong>pesquisador de IA</strong>, o Colab pode facilitar seu trabalho. Assista ao vídeo <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introdução ao Colab</a> para saber mais ou simplesmente comece a usá-lo abaixo!

# %% [markdown]
# ## <strong>Primeiros passos</strong>
#
# O documento que você está lendo não é uma página da Web estática, mas sim um ambiente interativo chamado <strong>notebook Colab</strong> que permite escrever e executar código.
#
# Por exemplo, aqui está uma <strong>célula de código</strong> com um breve script Python que calcula um valor, armazena-o em uma variável e imprime o resultado:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Para executar o código na célula acima, clique nela e depois pressione o botão Play à esquerda do código ou use o atalho do teclado "Command/Ctrl+Enter". Para editar o código, basta clicar na célula e começar a editar.
#
# As variáveis definidas em uma célula podem ser usadas mais tarde em outras células:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Os notebooks do Colab permitem combinar <strong>código executável</strong> e <strong>rich text</strong> em um só documento, além de <strong>imagens</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> e muito mais. Quando você cria seus próprios notebooks do Colab, eles são armazenados na sua conta do Google Drive. É possível compartilhar os notebooks do Colab facilmente com colegas de trabalho ou amigos e permitir que eles façam comentários ou até editem o documento. Para saber mais, consulte a <a href="/notebooks/basic_features_overview.ipynb">Visão Geral do Colab</a>. Para criar um novo notebook do Colab, use o menu Arquivo acima ou acesse o seguinte: <a href="http://colab.research.google.com#create=true">criar um novo notebook do Colab</a>.
#
# Os notebooks do Colab são notebooks do Jupyter hospedados no Colab. Para saber mais sobre o projeto Jupyter, acesse <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# ## Ciência de dados
#
# Com o Colab, você pode aproveitar todo o potencial das conhecidas bibliotecas Python para analisar e ver dados. A célula de códigos abaixo usa <strong>numpy</strong> para gerar dados aleatórios e <strong>matplotlib</strong> para visualizá-los. Para editar o código, basta clicar na célula e começar a editar.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# É possível importar para os notebooks do Colab os dados da sua conta do Google Drive, como planilhas. Também é possível importar do GitHub e de muitas outras fontes. Para saber mais sobre como importar dados e como o Colab pode ser usado para a ciência de dados, consulte o link abaixo em <a href="#working-with-data">Como trabalhar com dados</a>.

# %% [markdown]
# ## Machine learning
#
# Com o Colab, é possível importar um conjunto de dados de imagem, treinar um classificador de imagens dentro dele e avaliar o modelo, tudo com apenas <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">algumas linhas de código</a>. Os notebooks do Colab executam código dos servidores em nuvem do Google. Isso significa que você pode tirar proveito da potência de hardware do Google, como <a href="#using-accelerated-hardware">GPUs e TPUs</a>, independentemente da potência da sua máquina. Você só precisa de um navegador.

# %% [markdown]
# O Colab é usado amplamente pela comunidade de machine learning, para aplicações como:
# - Primeiros passos com o TensorFlow
# - Desenvolvimento e treinamento de redes neurais
# - Experimentos com TPUs
# - Divulgação de pesquisas em IA
# - Criação de tutoriais
#
# Para ver notebooks do Colab que demonstram aplicações de machine learning, consulte os <a href="#machine-learning-examples">exemplos de machine learning</a> abaixo.

# %% [markdown]
# ## Mais recursos
#
# ### Como trabalhar com Notebooks no Colab
# - [Visão geral do Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guia sobre Markdown](/notebooks/markdown_guide.ipynb)
# - [Importar bibliotecas e instalar dependências](/notebooks/snippets/importing_libraries.ipynb)
# - [Salvar e carregar notebooks no GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Formulários interativos](/notebooks/forms.ipynb)
# - [Widgets interativos](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 no Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Como trabalhar com dados
# - [Carregar dados: Drive, Planilhas e Google Cloud Storage](/notebooks/io.ipynb)
# - [Gráficos: visualizar dados](/notebooks/charts.ipynb)
# - [Primeiros passos com o BigQuery](/notebooks/bigquery.ipynb)
#
# ### Curso intensivo de machine learning
# Estes são alguns notebooks do curso on-line do Google sobre machine learning. Acesse o <a href="https://developers.google.com/machine-learning/crash-course/">site do curso completo</a> para saber mais.
# - [Introdução ao Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Regressão linear com tf.keras e uso de dados sintéticos](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Usar hardware acelerado
# - [TensorFlow com GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow com TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ### Exemplos em destaque
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>: use o kit de ferramentas para IA conversacional do Nvidia NeMo para trocar uma voz em um fragmento de áudio por uma gerada por computador.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Treinar novamente um classificador de imagens</a>: crie um modelo do Keras com base em um classificador de imagens pré-treinado para distinguir flores.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Classificação de texto</a>: classifique avaliações de filmes do IMDB como <em>positivas</em> ou <em>negativas</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Transferência de estilo</a>: use o aprendizado profundo para transferir o estilo entre imagens.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Perguntas e respostas sobre o codificador de frases universais multilíngue</a>: use um modelo de machine learning para responder a perguntas do conjunto de dados SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Interpolação de vídeo</a>: preveja o que aconteceu em um vídeo entre o primeiro e o último frames.
